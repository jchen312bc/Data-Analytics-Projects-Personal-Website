# %% [markdown]
# # Project 8: Going to the Movies

# %% [markdown]
# ## Your Information

# %% [markdown]
# At the start of each assignment, you will need to provide us your name and the name of the partner you worked with for this assignment (if you had one). Double click on the cell below or click once and hit enter to edit it. Replace "First Last" with your first name and last name. Replace "None" with the first and last name of your partner if you had one for this assignment. We ask for this information so we don't accuse you of cheating when your code looks like your partner's.
#
# Please keep these lines commented so they don't cause an error.

# %%
# MY NAME: Jiayi Chen
# MY PARTNER'S Name: Maria Soldatova

# %% [markdown]
# ## Imports

# %% [markdown]
# Every project will begin with some import statements. It's crucial that you run the cell below, otherwise we will not be able to grade your code and provide feedback to you.

# %%
import csv
import copy
import os
import random
import student_grader

# Set the LLM feedback language: 
# 1=English, 2=Mandarin Chinese, 3=Spanish, 4=Hindi, 5=Portuguese, 
# or use a string (e.g., "French")
student_grader.initialize(os.getcwd(), "p8", language=1)
# Out:
# LLM response will be generated in English.

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# In this assignment, you will...
#
# * integrate relevant information from various sources (e.g. multiple csv files),
# * build appropriate data structures for organization and informative presentation (e.g. list of dictionaries),
# * practice good coding style.

# %% [markdown]
# <h2 style="color:red">Warning (Note on Academic Misconduct):</h2>

# %% [markdown]
# **IMPORTANT**: **P8 and P9 are two parts of the same data analysis.** You **cannot** switch project partners between these two projects. That is if you partner up with someone for P8, you have to sustain that partnership until end of P9.
# Be careful not to work with more than one partner. If you work with a partner on Lab-P8, you are **not** allowed to finish your project with a different partner.
# You may either continue to work with the same partner, or work on P8 and P9 alone. Now may be a good time to review [our course policies](https://cs220.cs.wisc.edu/f25/syllabus.html).
#
# Under any circumstances, **no more than two students are allowed to work together on a project** as mentioned in the course policies. If your code is flagged by our code similarity detection tools, **both partners will be responsible** for sharing/copying the code, even if the code is shared/copied by one of the partners with/from other non-partner student(s). Note that each case of plagiarism will be reported to the Dean of Students with a zero grade on the project. **If you think that someone cannot be your project partner then don’t make that student your lab partner.**

# %% [markdown]
# ## Background Information

# %% [markdown]
# In P8 and P9, we will be working on a subset of the [IMDb Movies Dataset](https://www.imdb.com/interfaces/). We will use Python to discover some cool facts about our favorite movies, cast, and directors.
#
# In Lab-P8, you will work with the movies data sets, and practice writing some code to parse the data stored in `mapping.csv` and `movies.csv`. You can then use this code to parse other similar data sets in P8 and P9.

# %% [markdown]
# ## The Data

# %% [markdown]
# Open `movies.csv` and `mapping.csv` in any spreadsheet viewer, and see what the data looks like. When seen with a good spreadsheet viewer, this is what the first three lines of `movies.csv` will look like:
#
#
# |title|year|duration|genres|rating|directors|cast|
# | ----  |-----------------|-----------------------------|----------|---------------------------------------------------------------------|----------------------------------------------|--------|
# |tt0115953|1996|90|"Crime, Mystery, Thriller"|3.9|nm0915394|"nm0023858, nm0001614, nm0518715, nm0001457"|
# |tt0283453|2003|95|"Drama, Romance, Thriller"|5.5|nm0557751|"nm0000117, nm0121605, nm0000998, nm0694052"|
# |tt0447619|2006|102|"Adventure, Crime, Drama"|4.8|nm0630112|"nm0000899, nm0000366, nm0001953, nm0098793"|
#
#
# However, if you open the raw version of `movies.csv`, you are more likely to see something like this. It's the same data, but is sometimes a little harder to read:
# ```
# title,year,duration,genres,rating,directors,cast
# tt0115953,1996,90,"Crime, Mystery, Thriller",3.9,nm0915394,"nm0023858, nm0001614, nm0518715, nm0001457"
# tt0283453,2003,95,"Drama, Romance, Thriller",5.5,nm0557751,"nm0000117, nm0121605, nm0000998, nm0694052"
# tt0447619,2006,102,"Adventure, Crime, Drama",4.8,nm0630112,"nm0000899, nm0000366, nm0001953, nm0098793"
#
#
# ```
#
# The `title`, `directors`, and `cast` members are represented by their unique *IMDb ID* instead of their actual *names*. Now would be a good time to open `mapping.csv` to observe the data stored there. The first few lines should look like this:
#
# |         |           |
# | --------|-----|
# |tt7708470|The Bloody Man|
# |tt5759068|Freightened: The Real Price of Shipping|
# |tt0081541|The Under-Gifted|
# |tt1024962|Here We Are!|
# |tt0246875|Purely Belter|
# |tt0239341|Devi Putrudu|
# |tt0360960|Shadows of Time|
# |tt3215486|Idhu Kathirvelan Kadhal|
# |tt12792532|The Third War|
# |tt0070660|Seduction|
# |tt0284573|Transfixed|
# |tt14605182|Hell's Garden|
# |tt0043511|Europe '51|
# |tt0420215|The Spectator|
# |tt19514578|Shubh Yatra|
# |tt1837574|Hyena|

# %% [markdown]
# ## Lab Portion (12 Questions)

# %% [markdown]
# ### Segment 1: Loading Data from csv File
#
# In this segment, you will learn to parse the data in `movies.csv` and `mapping.csv`, and convert them into useful data structures.
#
# However, before we do any of that, **open `movies.csv` and `mapping.csv` within Jupyter Lab by double clicking on the file names** and look at the format in which the data is stored. Inspecting this data will be extremely useful when you try to read it in Python.

# %% [markdown]
# ### Task 1.1: Process `movies.csv`

# %%
# Here is the same 'process_csv' function from P6 and P7
def process_csv(filename):
    example_file = open(filename, encoding="utf-8")
    example_reader = csv.reader(example_file)
    example_data = list(example_reader)
    example_file.close()
    return example_data

# %%
# TODO: Use the code below to load the "movies.csv" file
csv_data = process_csv("movies.csv")

# %% [markdown]
# #### Lab Question 1

# %% [markdown]
# What is the **header** of the file `movies.csv`?
# Your output **must** be a **list** of **strings**.

# %% [markdown]
# Points possible: 4.0

# %%
# extract the header into csv_header variable
csv_header = csv_data[0]
csv_header
# Out:
# ['title', 'year', 'duration', 'genres', 'rating', 'directors', 'cast']

# %%
student_grader.check("lab-q1", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q1...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 2

# %% [markdown]
# What is the **data** (without the header) in the file `movies.csv`?
#
# Your output **must** be a **list** of **lists**.
#
# Since the data set is large, we only display the first three lines and will do so for the rest of the lab.

# %% [markdown]
# Points possible: 4.0

# %%
# extract just the data rows into csv_rows variable
csv_rows = csv_data[1:]
csv_rows[:3]
# Out:
# [['tt0115953',
#   '1996',
#   '90',
#   'Crime, Mystery, Thriller',
#   '3.9',
#   'nm0915394',
#   'nm0023858, nm0001614, nm0518715, nm0001457'],
#  ['tt0283453',
#   '2003',
#   '95',
#   'Drama, Romance, Thriller',
#   '5.5',
#   'nm0557751',
#   'nm0000117, nm0121605, nm0000998, nm0694052'],
#  ['tt0447619',
#   '2006',
#   '102',
#   'Adventure, Crime, Drama',
#   '4.8',
#   'nm0630112',
#   'nm0000899, nm0000366, nm0001953, nm0098793']]

# %%
student_grader.check("lab-q2", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q2...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Task 1.2: Convert your `mapping` to a `dict`

# %% [markdown]
# #### Lab Question 3

# %% [markdown]
# What is the **data** in the file `mapping.csv`?
#
# Your output **must** be a **list** of **lists**. There is no header in `mapping.csv`, so you should **not** slice off the first row here.
#
# Since the data set is large, we only display the first ten lines and will do so for the rest of the lab.

# %% [markdown]
# Points possible: 4.0

# %%
# use process_csv to read `mapping.csv` into a list of lists data structure
mapping_rows = process_csv("mapping.csv")
mapping_rows[:10]
# Out:
# [['tt7708470', 'The Bloody Man'],
#  ['tt5759068', 'Freightened: The Real Price of Shipping'],
#  ['tt0081541', 'The Under-Gifted'],
#  ['tt1024962', 'Here We Are!'],
#  ['tt0246875', 'Purely Belter'],
#  ['tt0239341', 'Devi Putrudu'],
#  ['tt0360960', 'Shadows of Time'],
#  ['tt3215486', 'Idhu Kathirvelan Kadhal'],
#  ['tt12792532', 'The Third War'],
#  ['tt0070660', 'Seduction']]

# %%
student_grader.check("lab-q3", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q3...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# Currently `mapping_rows` is a **list** of **lists**.  To make it more useful, let us convert it to a **dict** with the *ID* as the **key** and the *name* as the **value**, like this:
#
# ```python
# {"tt7708470": "The Bloody Man"
#  "tt5759068": "Freightened: The Real Price of Shipping"
#  "tt0081541": "The Under-Gifted"
#  "tt1024962": "Here We Are!"
#  "tt0246875": "Purely Belter"
#  "tt0239341": "Devi Putrudu"
#  "tt0360960": "Shadows of Time"
#  "tt3215486": "Idhu Kathirvelan Kadhal"
#  "tt12792532": "The Third War"
#  "tt0070660": "Seduction"
#  "tt0284573": "Transfixed"
#  "tt14605182": "Hell's Garden"
#  "tt0043511": "Europe '51"
#  "tt0420215": "The Spectator"
#  "tt19514578": "Shubh Yatra"
#  "tt1837574": "Hyena"}
# ```

# %% [markdown]
# #### Lab Question 4

# %% [markdown]
# Display the **data** in the file `mapping.csv` as a **dictionary**.
#
# Your output **must** be a **dictionary**.
#
# It is acceptable for you to *hardcode* **column indices** here. This is because this csv file does not have a header, and it is **implicit** that the first string is the ID and that the second string is the name associated with the ID. For csv files which have headers, you should **never** hardcode **column indices**.
#
# We will not display the dictionary because it is long, so we will display the length instead (length: 5823). However the next few questions will check to make sure you've correctly created the dictionary.

# %% [markdown]
# Points possible: 8.0

# %%
mapping_dict = {} # initialize an empty dictionary into the variable mapping_dict
# TODO: iterate over each row of the mapping dataset
for row in mapping_rows:
    # TODO: insert the correct key-value pair into mapping_dict
    mapping_dict[row[0]] = row[1]
len(mapping_dict)
# Out:
# 5824

# %%
student_grader.check("lab-q4", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q4...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 5

# %% [markdown]
# What is the **value** associated with the key *tt3469046* in `mapping_dict`?

# %% [markdown]
# Points possible: 4.0

# %%
# replace the ... with your code
tt3469046_value = mapping_dict['tt3469046']
tt3469046_value
# Out:
# 'Despicable Me 3'

# %%
student_grader.check("lab-q5", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q5...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Task 1.3.1: Convert a list of lists to a list of dictionaries
#
# Now, let's go back to `movies.csv`. Your variable `csv_rows` (defined above in Question 2) should look like this:
#
# ```python
# [['tt0115953',
#   '1996',
#   '90',
#   'Crime, Mystery, Thriller',
#   '3.9',
#   'nm0915394',
#   'nm0023858, nm0001614, nm0518715, nm0001457'],
#  ['tt0283453',
#   '2003',
#   '95',
#   'Drama, Romance, Thriller',
#   '5.5',
#   'nm0557751',
#   'nm0000117, nm0121605, nm0000998, nm0694052'],
#  ['tt0447619',
#   '2006',
#   '102',
#   'Adventure, Crime, Drama',
#   '4.8',
#   'nm0630112',
#   'nm0000899, nm0000366, nm0001953, nm0098793']]
# ```

# %% [markdown]
# It's a list of lists without its header. To make it easier to access data, let us convert it to a **list** of **dictionaries**. The data structure should look like:
#
# ```python
# [{'title': 'tt0115953',
#   'year': '1996',
#   'duration': '90',
#   'genres': 'Crime, Mystery, Thriller',
#   'rating': '3.9',
#   'directors': 'nm0915394',
#   'cast': 'nm0023858, nm0001614, nm0518715, nm0001457'},
#  {'title': 'tt0283453',
#   'year': '2003',
#   'duration': '95',
#   'genres': 'Drama, Romance, Thriller',
#   'rating': '5.5',
#   'directors': 'nm0557751',
#   'cast': 'nm0000117, nm0121605, nm0000998, nm0694052'},
#  {'title': 'tt0447619',
#   'year': '2006',
#   'duration': '102',
#   'genres': 'Adventure, Crime, Drama',
#   'rating': '4.8',
#   'directors': 'nm0630112',
#   'cast': 'nm0000899, nm0000366, nm0001953, nm0098793'}]
# ```

# %% [markdown]
# #### Lab Question 6

# %% [markdown]
# Store the **first** movie in the file `movies.csv` as a **dictionary**.
#
# It should be noted that the dataset file has a **header** that must be used. You **must** use the `list.index` method to identify the column indices from the column name, just as you did in P6 and P7.

# %% [markdown]
# Points possible: 20.0

# %%
first_movie = {} # initialize an empty dictionary
first_movie["title"] = csv_rows[0][csv_header.index("title")] # csv_rows[0][csv_header.index(...)]
first_movie["year"] = csv_rows[0][csv_header.index("year")]
# TODO: add the other columns to first_movie
first_movie["duration"] = csv_rows[0][csv_header.index("duration")]
first_movie["genres"] = csv_rows[0][csv_header.index("genres")]
first_movie["rating"] = csv_rows[0][csv_header.index("rating")]
first_movie["directors"] = csv_rows[0][csv_header.index("directors")]
first_movie["cast"] = csv_rows[0][csv_header.index("cast")]

first_movie
# Out:
# {'title': 'tt0115953',
#  'year': '1996',
#  'duration': '90',
#  'genres': 'Crime, Mystery, Thriller',
#  'rating': '3.9',
#  'directors': 'nm0915394',
#  'cast': 'nm0023858, nm0001614, nm0518715, nm0001457'}

# %%
student_grader.check("lab-q6", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q6...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 7

# %% [markdown]
# Display the **data** in the file `movies.csv` as a **list** of **dictionaries**.

# %% [markdown]
# Points possible: 20.0

# %%
raw_movies_list = [] # use this empty list to append your dictionary
# TODO: loop through all the rows of csv_rows
# TODO: create a dictionary similar to the one in question 6 for each movie
# TODO: add each movie dictionary to raw_movies_list

for row in csv_rows:
    movie_dict = {} 
    movie_dict["title"] = row[csv_header.index("title")]
    movie_dict["year"] = row[csv_header.index("year")]
    movie_dict["duration"] = row[csv_header.index("duration")]
    movie_dict["genres"] = row[csv_header.index("genres")]
    movie_dict["rating"] = row[csv_header.index("rating")]
    movie_dict["directors"] = row[csv_header.index("directors")]
    movie_dict["cast"] = row[csv_header.index("cast")]
    
    raw_movies_list.append(movie_dict)

raw_movies_list[:3]
# Out:
# [{'title': 'tt0115953',
#   'year': '1996',
#   'duration': '90',
#   'genres': 'Crime, Mystery, Thriller',
#   'rating': '3.9',
#   'directors': 'nm0915394',
#   'cast': 'nm0023858, nm0001614, nm0518715, nm0001457'},
#  {'title': 'tt0283453',
#   'year': '2003',
#   'duration': '95',
#   'genres': 'Drama, Romance, Thriller',
#   'rating': '5.5',
#   'directors': 'nm0557751',
#   'cast': 'nm0000117, nm0121605, nm0000998, nm0694052'},
#  {'title': 'tt0447619',
#   'year': '2006',
#   'duration': '102',
#   'genres': 'Adventure, Crime, Drama',
#   'rating': '4.8',
#   'directors': 'nm0630112',
#   'cast': 'nm0000899, nm0000366, nm0001953, nm0098793'}]

# %%
student_grader.check("lab-q7", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q7...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 8

# %% [markdown]
# What is the `title` *ID* of the **first** movie in your list?
#
# Your output **must** be a **string**. You must answer this question by querying the value from the `raw_movies_list` data structure.

# %% [markdown]
# Points possible: 4.0

# %%
# we have done this one for you
first_movie_title = raw_movies_list[0]['title']
first_movie_title
# Out:
# 'tt0115953'

# %%
student_grader.check("lab-q8", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q8...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 9

# %% [markdown]
# What are the `genres` of the **second** movie in your list?
#
# Your output **must** be a **string**. You **must** answer this question by querying the value from the `raw_movies_list` data structure.

# %% [markdown]
# Points possible: 4.0

# %%
# compute and store the answer in the variable 'second_movie_genres', then display it
second_movie_genres = raw_movies_list[1]['genres']
second_movie_genres
# Out:
# 'Drama, Romance, Thriller'

# %%
student_grader.check("lab-q9", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q9...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Task 1.3.2: Convert the `int` and `float` values to the correct type
#
# Did you notice that currently all the values in the dictionaries are **strings**? We should convert them into correct types. In particular, the `year` and `duration` should be data type **int** and the `rating` should be a **float**.
#
# After converting the **int** and **float** values to the right types, your list of dictionaries should look like:
#
# ```python
# [{'title': 'tt0115953',
#   'year': 1996,
#   'duration': 90,
#   'genres': 'Crime, Mystery, Thriller',
#   'rating': 3.9,
#   'directors': 'nm0915394',
#   'cast': 'nm0023858, nm0001614, nm0518715, nm0001457'},
#  {'title': 'tt0283453',
#   'year': 2003,
#   'duration': 95,
#   'genres': 'Drama, Romance, Thriller',
#   'rating': 5.5,
#   'directors': 'nm0557751',
#   'cast': 'nm0000117, nm0121605, nm0000998, nm0694052'},
#  {'title': 'tt0447619',
#   'year': 2006,
#   'duration': 102,
#   'genres': 'Adventure, Crime, Drama',
#   'rating': 4.8,
#   'directors': 'nm0630112',
#   'cast': 'nm0000899, nm0000366, nm0001953, nm0098793'}]
# ```

# %% [markdown]
# #### Lab Question 10

# %% [markdown]
# Store the **data** in the file `movies.csv` as a **list** of **dictionaries** with the correct data types.
#
# The `year` and `duration` values **must** be of data type **int** and the `rating` value **must** be a **float**.

# %% [markdown]
# Points possible: 20.0

# %%
mostly_raw_movies_list = [] # use this empty list to append your dictionaies below
for movie in raw_movies_list: # loop (directly) through movies in raw_movies_list
    new_movie = {} # create an empty dictionary to insert values for each movie
    new_movie['title'] = movie["title"]# extract the title from movie to new_movie
    new_movie['year'] = int(movie['year']) # convert the year from movie into an int and save in new_movie
    # TODO: add the other columns (with the required data types) to new_movie
    new_movie["duration"] = int(movie["duration"])
    new_movie["genres"] = movie["genres"]
    new_movie["rating"] = float(movie["rating"])
    new_movie["directors"] = movie["directors"]
    new_movie["cast"] = movie["cast"]
    
    # TODO: add new_movie to mostly_raw_movies_list
    mostly_raw_movies_list.append(new_movie)

mostly_raw_movies_list[:3]
# Out:
# [{'title': 'tt0115953',
#   'year': 1996,
#   'duration': 90,
#   'genres': 'Crime, Mystery, Thriller',
#   'rating': 3.9,
#   'directors': 'nm0915394',
#   'cast': 'nm0023858, nm0001614, nm0518715, nm0001457'},
#  {'title': 'tt0283453',
#   'year': 2003,
#   'duration': 95,
#   'genres': 'Drama, Romance, Thriller',
#   'rating': 5.5,
#   'directors': 'nm0557751',
#   'cast': 'nm0000117, nm0121605, nm0000998, nm0694052'},
#  {'title': 'tt0447619',
#   'year': 2006,
#   'duration': 102,
#   'genres': 'Adventure, Crime, Drama',
#   'rating': 4.8,
#   'directors': 'nm0630112',
#   'cast': 'nm0000899, nm0000366, nm0001953, nm0098793'}]

# %%
student_grader.check("lab-q10", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q10...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 11

# %% [markdown]
# What is the `duration` of the **first** movie in your list?
#
# You must answer this question by querying the value from the `mostly_raw_movies_list` structure.

# %% [markdown]
# Points possible: 4.0

# %%
# We have done this one for you
first_movie_duration = mostly_raw_movies_list[0]["duration"]
first_movie_duration
# Out:
# 90

# %%
student_grader.check("lab-q11", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q11...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Lab Question 12

# %% [markdown]
# What is the `rating` of the **first** movie in your list?

# %% [markdown]
# Points possible: 4.0

# %%
# Replace the ... with your code
first_movie_rating = mostly_raw_movies_list[0]["rating"]
first_movie_rating
# Out:
# 3.9

# %%
student_grader.check("lab-q12", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for lab-q12...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Great work! You are now ready to submit lab-p8.
#
# ### Submitting the lab
#
#  **Submit your p8.ipynb on Gradescope to the lab-p8 assignment**, like usual. Remember that the grades for the lab portion of the project and the actual assignment grade are independent. You will submit the same notebook (at different levels of completion) to two different assignments.

# %% [markdown]
# ## Project Portion (27 Questions, 5 Functions)

# %% [markdown]
# You **may not** hardcode indices in your code, unless the question explicitly asks you to do so. If you open your `.csv` files with Excel, manually count through the rows and use this number to loop through the dataset, this is also considered as hardcoding. If any instances of hardcoding are found during code review, the Gradescope autograder will **deduct** points from your score.
#
# **Store** your final answer for each question in the **variable specified for each question**. This step is important because the autograder works by comparing the value of this variable against the correct answer.
#
# For some of the questions, we'll ask you to write (then use) a function to compute the answer. If you compute the answer **without** creating the function we ask you to write, the autograder will **deduct** points from your score, even if the way you did it produced the correct answer.
#
# #### Required Functions:
# - `get_mapping`
# - `get_raw_movies`
# - `get_movies`
# - `find_specific_movies`
# - `bucketize_by_genre`
#
# In this project, you will also be required to define certain **data structures**. If you do not create these data structures exactly as specified, the autograder will **deduct** points from your score, even if the way you did it produced the correct answer.
#
# #### Required Data Structures:
# - `movies`
# - `genre_dict`
#
# You are only allowed to define these data structures **once** and the autograder will **deduct** points from your score if you redefine the values of these variables.
#
# In this project (and the next), you will be asked to create **lists** of movies. For all such questions, **unless it is explicitly mentioned otherwise**, the movies should be in the **same order** as in the `movies.csv` file. Similarly, for each movie, the **list** of `genres`, `directors`, and `cast` members should always be in the **same order** as in the `movies.csv` file.
#
# Students are only allowed to use Python commands and concepts that have been taught in the course prior to the release of P8. Therefore, you should not use the pandas module. The autograder will **deduct** points from your score otherwise.
#
# In addition, you are also **required** to follow the requirements below:
# - **Do not use the method `csv.DictReader` for P8**. Although the required output can be obtained using this method, one of the learning outcomes of this project is to demonstrate your ability to build dictionaries with your own code.
# - Additional import statements beyond those that are stated in the directions are not allowed. For this project, we allow you to use the `csv` and `copy` packages (that is, you can use the `import csv` and `import copy` statements in your submission). You should not use concepts / modules that are yet to be covered in this course; for example: you should **not** use modules like `pandas`.
#
# The autograder will **deduct** points accordingly, if you don't follow the provided directions.

# %% [markdown]
# ### Segment 1: Loading Data from csv File (Continued)
#
# Make sure to run the cells from the lab section before starting this part.

# %% [markdown]
# ### Task 1.3.3: Convert the `genres`, `directors`, and `cast` to list of strings

# %% [markdown]
# Run the next cell and observe its output.

# %%
# these are the 'genres' of the first movie
mostly_raw_movies_list[0]["genres"]
# Out:
# 'Crime, Mystery, Thriller'

# %% [markdown]
# Notice that the `genres` are stored as a *single* **string**. It would be much more useful to store this value as a **list** of *three different* **strings**, with each **string** representing a *single* **genre**:
#
# `['Crime', 'Mystery', 'Thriller']`
#
# Unfortunately, the CSV file format cannot represent **lists**, so **lists** of **strings** are often represented as a *single* **string** with the values separated by a comma followed by a space. So, we will have to convert the **string** into a **list** of **strings** ourselves.
#
# In the `movies.csv` dataset, the `directors` and `cast` are similarly stored as a *single* **string** with the values separated by a comma followed by a space (`", "`). We are now going to convert the value corresponding to the keys `genres`, `casts`, and `directors` to a **list** of **strings**. The output **must** be a **list** of **dictionaries** in the following format:
#
# ```python
#    {
#         'title': <title-id>,
#         'year': <the year as an integer>,
#         'duration': <the duration as an integer>,
#         'genres': [<genre1>, <genre2>, ...],
#         'rating': <the rating as a float>,
#         'directors': [<director-id1>, <director-id2>, ...],
#         'cast': [<actor-id1>, <actor-id2>, ....]
#     }
# ```
#
# After converting the strings to list of strings, the **list** of **dictionaries** should look like:
#
# ```python
#     [{'title': 'tt0115953',
#       'year': 1996,
#       'duration': 90,
#       'genres': ['Crime', 'Mystery', 'Thriller'],
#       'rating': 3.9,
#       'directors': ['nm0915394'],
#       'cast': ['nm0023858', 'nm0001614', 'nm0518715', 'nm0001457']},
#      {'title': 'tt0283453',
#       'year': 2003,
#       'duration': 95,
#       'genres': ['Drama', 'Romance', 'Thriller'],
#       'rating': 5.5,
#       'directors': ['nm0557751'],
#       'cast': ['nm0000117', 'nm0121605', 'nm0000998', 'nm0694052']},
#      {'title': 'tt0447619',
#       'year': 2006,
#       'duration': 102,
#       'genres': ['Adventure', 'Crime', 'Drama'],
#       'rating': 4.8,
#       'directors': ['nm0630112'],
#       'cast': ['nm0000899', 'nm0000366', 'nm0001953', 'nm0098793']}]
# ```

# %% [markdown]
# #### Project Question 1

# %% [markdown]
# Store the **data** in the file `movies.csv` as a **list** of **dictionaries** with the fields `genres`, `directors`, and `cast` converted to a list of strings.
#
# The `genres`, `directors`, and `cast` values **must** be **lists** of **strings**.
#
# **Hint:** Recall that there is a **string method** that enables you to perform this. If you don't know where to start, please review any of the lecture notes from Lecture 14. Note that CSV values must be split **on a comma followed by a space (", ")**.
#
# [Mike's lecture notes on lists](https://canvas.wisc.edu/courses/478867/files/folder/Mikes_Lecture_Notes/lec14_lists)
#
# [Kate's lecture notes on lists](https://canvas.wisc.edu/courses/478867/files/folder/Kates_Lecture_Notes/lec14_lists)

# %% [markdown]
# Points possible: 5.0

# %%
semi_raw_movies_list = [] # use this empty list to append your dictionaries below
for movie in mostly_raw_movies_list: # loop through movies in mostly_raw_movies_list
    new_movie = {} # create an empty dictionary to insert values for each movie
    new_movie['title'] = movie['title'] # extract the title of movie 
    new_movie['year'] = int(movie['year']) # extract the year of movie 
    new_movie['duration'] = int(movie['duration']) # extract the duration of movie 
    new_movie['genres'] = movie["genres"].split(", ")# split the genres into a list of strings
    
    # TODO: add the other columns (with the required data types) to new_movie
    new_movie["rating"] = float(movie["rating"])
    new_movie["directors"] = movie["directors"].split(", ")
    new_movie["cast"] = movie["cast"].split(", ")
    
    # TODO: add new_movie to semi_raw_movies_list
    semi_raw_movies_list.append(new_movie)
    
semi_raw_movies_list[:3]
# Out:
# [{'title': 'tt0115953',
#   'year': 1996,
#   'duration': 90,
#   'genres': ['Crime', 'Mystery', 'Thriller'],
#   'rating': 3.9,
#   'directors': ['nm0915394'],
#   'cast': ['nm0023858', 'nm0001614', 'nm0518715', 'nm0001457']},
#  {'title': 'tt0283453',
#   'year': 2003,
#   'duration': 95,
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'rating': 5.5,
#   'directors': ['nm0557751'],
#   'cast': ['nm0000117', 'nm0121605', 'nm0000998', 'nm0694052']},
#  {'title': 'tt0447619',
#   'year': 2006,
#   'duration': 102,
#   'genres': ['Adventure', 'Crime', 'Drama'],
#   'rating': 4.8,
#   'directors': ['nm0630112'],
#   'cast': ['nm0000899', 'nm0000366', 'nm0001953', 'nm0098793']}]

# %%
student_grader.check("q1", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q1...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 2

# %% [markdown]
# How **many** `cast` members are there in the **second** movie?
#
# You **must** answer this question by querying the value from the `semi_raw_movies_list` data structure.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code
second_movie_num_cast = len(semi_raw_movies_list[1]["cast"])
second_movie_num_cast
# Out:
# 4

# %%
student_grader.check("q2", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q2...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Segment 2: Mapping IDs to Actual Names
#
# As mentiond above, `title`, `directors`, and `cast` are represented by *IDs* rather than actual *names*. To make our data more intuitive, we next need to **convert** these *IDs* to actual *names*. The output **must** be a **list** of **dictionaries** in the following format:
#
# ```python
#    {
#         'title': "the movie name",
#         'year': <the year as an integer>,
#         'duration': <the duration as an integer>,
#         'genres': [<genre1>, <genre2>, ...],
#         'rating': <the rating as a float>,
#         'directors': ["director-name1", "director-name2", ...],
#         'cast': ["actor-name1", "actor-name2", ....]
#     }
# ```
#
# After converting the IDs to actual names, your **list** of **dictionaries** should look like:
#
# ```python
# [{'title': 'Countdown',
#   'year': 1996,
#   'duration': 90,
#   'genres': ['Crime', 'Mystery', 'Thriller'],
#   'rating': 3.9,
#   'directors': ['Keoni Waxman'],
#   'cast': ['Yûki Amami', 'Lori Petty', 'Jason London', 'James Le Gros']},
#  {'title': 'Lost Junction',
#   'year': 2003,
#   'duration': 95,
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'rating': 5.5,
#   'directors': ['Peter Masterson'],
#   'cast': ['Neve Campbell', 'Billy Burke', 'Jake Busey', 'Charles Edwin Powell']},
#  {'title': 'The Stone Council',
#   'year': 2006,
#   'duration': 102,
#   'genres': ['Adventure', 'Crime', 'Drama'],
#   'rating': 4.8,
#   'directors': ['Guillaume Nicloux'],
#   'cast': ['Monica Bellucci', 'Catherine Deneuve', 'Moritz Bleibtreu', 'Sami Bouajila']}]
# ```

# %% [markdown]
# ### Task 2.1: Find the Actual Names
#
# Run the cell below and try to understand its output, which will be necessary for the next several questions.

# %%
title_id = semi_raw_movies_list[0]["title"] # extract the title of the first movie
title = mapping_dict[title_id] # recall the dictionary mapping_dict from q4
print(title_id + ": " + title)
# Out:
# tt0115953: Countdown

# %% [markdown]
# #### Project Question 3

# %% [markdown]
# What is the `title` of the **second** movie in your list?
#
# Your output **must** be a **string** of the *name* and **not** the *ID*. You **must** answer this question by querying values from the `semi_raw_movies_list` and `mapping_dict` data structures.

# %% [markdown]
# Points possible: 4.0

# %%
# compute and store the answer in the variable 'title_second', then display it
title_second = mapping_dict[semi_raw_movies_list[1]["title"]]

title_second
# Out:
# 'Lost Junction'

# %%
student_grader.check("q3", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q3...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 4

# %% [markdown]
# List the **names** of the `cast` of the **first** movie in your list.
#
# Your output **must** be a *list* of the *names* and **not** the *IDs*. You **must** answer this question by querying values from the `semi_raw_movies_list` and `mapping_dict` data structures.

# %% [markdown]
# Points possible: 4.0

# %%
cast_names = [] # empty list to store the names of the cast members
first_movie = semi_raw_movies_list[0] # semi_raw_movies_list[...] # extract the dictionary of the first movie
# TODO: iterate over the IDs of the cast members of first_movie
    # take each cast member's ID and look up the value from the mapping_dict dict
    # add each cast member's name to the list 'cast_names'

cast_mem_ids = first_movie["cast"]

for cast_mem_id in cast_mem_ids:
    cast_names.append(mapping_dict[cast_mem_id])

cast_names
# Out:
# ['Yûki Amami', 'Lori Petty', 'Jason London', 'James Le Gros']

# %%
student_grader.check("q4", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q4...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Task 2.2: Convert to Actual Names
#
# Use your `mapping_dict` and `semi_raw_movies_list` to finish this task.
# There are three columns (`title`, `directors`, and `cast`) which need to be converted.

# %% [markdown]
# #### Project Question 5

# %% [markdown]
# Use your `mapping_dict` and `semi_raw_movies_list` to convert the **data** from `movies.csv` into **list** of **dictionaries**, which will be stored in `movies_list`.
#
# The `title`, `directors` and `cast` values **must** be **actual names** instead of **IDs**.

# %% [markdown]
# Points possible: 5.0

# %%
movies_list = [] # use this empty list to append your dictionaries below

for movie in semi_raw_movies_list:
    new_movie = {}
    new_movie["title"] = mapping_dict[movie["title"]]
    new_movie['year'] = int(movie['year'])
    new_movie['duration'] = int(movie['duration']) 
    new_movie['genres'] = movie["genres"]
    new_movie["rating"] = float(movie["rating"])
    new_movie["directors"] = [mapping_dict[d] for d in movie["directors"]]  
    new_movie["cast"] = [mapping_dict[c] for c in movie["cast"]]
    
    movies_list.append(new_movie)

movies_list[:3]
# Out:
# [{'title': 'Countdown',
#   'year': 1996,
#   'duration': 90,
#   'genres': ['Crime', 'Mystery', 'Thriller'],
#   'rating': 3.9,
#   'directors': ['Keoni Waxman'],
#   'cast': ['Yûki Amami', 'Lori Petty', 'Jason London', 'James Le Gros']},
#  {'title': 'Lost Junction',
#   'year': 2003,
#   'duration': 95,
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'rating': 5.5,
#   'directors': ['Peter Masterson'],
#   'cast': ['Neve Campbell',
#    'Billy Burke',
#    'Jake Busey',
#    'Charles Edwin Powell']},
#  {'title': 'The Stone Council',
#   'year': 2006,
#   'duration': 102,
#   'genres': ['Adventure', 'Crime', 'Drama'],
#   'rating': 4.8,
#   'directors': ['Guillaume Nicloux'],
#   'cast': ['Monica Bellucci',
#    'Catherine Deneuve',
#    'Moritz Bleibtreu',
#    'Sami Bouajila']}]

# %%
student_grader.check("q5", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q5...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 6

# %% [markdown]
# What is the movie `title` of the **first** movie in your list?

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code
first_movie_title = movies_list[0]["title"]
first_movie_title
# Out:
# 'Countdown'

# %%
student_grader.check("q6", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q6...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 7

# %% [markdown]
# Who are the `directors` of the **second movie** in your list?
#
# Your output **must** be a **list** of **strings**. You **must** answer this question by querying the value from the `movies_list` data structure.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'second_movie_directors', then display it
second_movie_directors = movies_list[1]["directors"]
second_movie_directors
# Out:
# ['Peter Masterson']

# %%
student_grader.check("q7", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q7...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Segment 3: Working with Functions
#
# You now have all the background you need to write the project functions and use them for data analysis!
#
# **Note:** you are free to use/modify code from the lab and Section 1 of the Project, and are in fact encouraged to do so when convenient!

# %% [markdown]
# #### Project Function 1: `get_mapping(path)`

# %% [markdown]
# We require you to complete the below function to answer the next several questions (this is a **requirement**, and you will **lose points** if you do not implement this function).
#
# The `get_mapping(path)` function must return a dictionary where each key is from the first column of the mapping file and the value is the second column of the mapping file.  For example, if `get_mapping('movies.csv')` is called, a dictionary will be created where one of the keys would be `tt15239678` and it would map to the value `Barbie`. See **Lab Q4** for additional guidance.

# %% [markdown]
# Points possible: 4.0

# %%
def get_mapping(path):
    """
    get_mapping(path) converts a mapping csv in 'path' 
    into a dict with keys as IDs and values as names
    """
    csv_rows = process_csv(path)
    mapping = {}
    for row in csv_rows:
        mapping[row[0]]= row[1]
    return mapping # replace with your code
#     TODO: call process_csv() with the path to get a list of lists
#     TODO: create an empty dictionary  
#     TODO: iterate through each row of the list of lists returned by process_csv()
#     TODO: map value in first column (ID) to value in second column (name/title)

# %%
student_grader.check("get_mapping", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for get_mapping...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 8

# %% [markdown]
# What is returned by `get_mapping("mapping.csv")`?
#
# You must define a variable `mapping` which **must** store a **dictionary** mapping the *IDs* in `mapping.csv` to *names*.
#
# Do not display the `mapping`.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'mapping', do NOT display it   
mapping = get_mapping("mapping.csv")

# %%
student_grader.check("q8", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q8...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 9

# %% [markdown]
# What is the **value** associated with the **key** *nm1739764*?
#
# Your output **must** be a **string** stored in a variable named `nm1739764_value`. You **must** use the variable `mapping` defined above to answer this question. You should not call the function `get_mapping()` again on this dataset.

# %% [markdown]
# Points possible: 2.0

# %%
# access and store the answer in the variable 'nm1739764_value', then display it
nm1739764_value  = mapping['nm1739764']
nm1739764_value
# Out:
# 'Maaike Neuville'

# %%
student_grader.check("q9", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q9...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 10

# %% [markdown]
# What are the **values** associated with **keys** that **begin** with *nm*?
#
# Your output **must** be a **list** of **strings** stored in a variable named `nm_mappings`. You **must** find **only** the values of the keys that **begin** with *nm*, and **not** the keys that contain *nm*. You **must** use the variable `mapping` defined above to answer this question. Duplicates are okay.
#
# Display the first 10 names.

# %% [markdown]
# Points possible: 4.0

# %%
# compute and store the answer in the variable 'nm_mappings', then display the first 10 names
nm_mappings = []

for key in mapping:
    if key[:2] == "nm":
        nm_mappings.append(mapping[key])
    else:
        continue

nm_mappings[:10]
# Out:
# ['Giorgi Tsereteli',
#  'Henri Vidal',
#  'Leslie Jordan',
#  'Stella Májová',
#  'Lucian Msamati',
#  'Lukas Moodysson',
#  'Penny Singleton',
#  "Michael O'Keefe",
#  'Giorgos Giannopoulos',
#  'Mahtab Nasirpour']

# %%
student_grader.check("q10", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q10...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 11

# %% [markdown]
# Find the **keys** of the people (keys **beginning** with *nm*) whose **last name** is **exactly** *Murphy*.
#
# Your output **must** be a **list** of **string(s)** stored in a variable named `nm_murphy`. You **must** use the variable `mapping` defined above to answer this question.

# %% [markdown]
# Points possible: 4.0

# %%
# compute and store the answer in the variable 'nm_murphy', then display it
nm_murphy = []
for key in mapping:
    if key.startswith('nm'):
        name = mapping[key].split(" ")
        if name[-1] == "Murphy":
            nm_murphy.append(key)
        
nm_murphy
# Out:
# ['nm0614151', 'nm0614755', 'nm0614165', 'nm3680095', 'nm0001559', 'nm1789678']

# %%
student_grader.check("q11", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q11...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Function 2: `get_raw_movies(path)`

# %% [markdown]
# Now, let's move on to reading the movie files!
#
# We require you to complete the below function to answer the next several questions (this is a **requirement**, and you will **lose points** if you do not implement this function).
#
# This function **must** return a **list** of **dictionaries**, where each **dictionary** is of the following format:
#
# ```python
#    {
#         'title': <title-id>,
#         'year': <the year as an integer>,
#         'duration': <the duration as an integer>,
#         'genres': [<genre1>, <genre2>, ...],
#         'rating': <the rating as a float>,
#         'directors': [<director-id1>, <director-id2>, ...],
#         'cast': [<actor-id1>, <actor-id2>, ....]
#     }
# ```
#
# Here is an example:
#
# ```python
#     {
#         'title': 'tt0033313',
#         'year': 1941,
#         'duration': 59,
#         'genres': ['Western'],
#         'rating': 5.2,
#         'directors': ['nm0496505'],
#         'cast': ['nm0193318', 'nm0254381', 'nm0279961', 'nm0910294', 'nm0852305']
#     }
# ```
#
# You may use code from the lab portion of the  notebook to finish this function (e.g. calling `process_csv()`).

# %% [markdown]
# Points possible: 5.0

# %%
def get_raw_movies(path):
    """
    get_raw_movies(path) converts a movies csv in 'path' (a 
    string containing a file path) into a list of dicts with
    column names as keys and the corresponding type converted 
    values as the values
    """
    raw_movies_list = []
    csv_rows = process_csv(path)
        
    for row in csv_rows[1:]:
        movie_dict = {} 
        movie_dict["title"] = row[csv_header.index("title")]
        movie_dict["year"] = int(row[csv_header.index("year")])
        movie_dict["duration"] = int(row[csv_header.index("duration")])
        movie_dict["genres"] = row[csv_header.index("genres")].split(", ")
        movie_dict["rating"] = float(row[csv_header.index("rating")])
        movie_dict["directors"] = row[csv_header.index("directors")].split(", ")
        movie_dict["cast"] = row[csv_header.index("cast")].split(", ")
        
        raw_movies_list.append(movie_dict)

    return raw_movies_list

# %%
student_grader.check("get_raw_movies", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for get_raw_movies...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 12

# %% [markdown]
# What is returned by `get_raw_movies("movies.csv")`?
#
# Your output **must** be a **list** of **dictionaries** where each dictionary contains information about a movie.
#
# Display the first 3 elements.
#
# **Note:** If your answer looks correct, but does not pass the autograder, make sure that the **datatypes** are all correct. Also make sure that the **directors** and **cast** are in the **same order** as in `movies.csv`.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'raw_movies', then display the first 3 elements
raw_movies = get_raw_movies("movies.csv")

# %%
student_grader.check("q12", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q12...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 13

# %% [markdown]
# How **many** cast members does the **first** movie have?
#
# Your output **must** be an **int**. You **must** use the variable `raw_movies` defined above to answer this question. Avoid reconstructing large data structures unnecessarily, for example, do not call `get_raw_movies` again, as this wastes time, adds unnecessary load to the autograder, and is considered poor coding practice.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'num_cast_first_movie', then display it
num_cast_first_movie = len(raw_movies[0]["cast"])
num_cast_first_movie
# Out:
# 4

# %%
student_grader.check("q13", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q13...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 14

# %% [markdown]
# What is the *ID* of the **first** cast member listed for the **first** movie of the dataset?
#
# Your output **must** be a **string**. You **must** use the variable `raw_movies` defined above to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'first_actor_id_first_movie', then display it
first_actor_id_first_movie = raw_movies[0]["cast"][0]
first_actor_id_first_movie
# Out:
# 'nm0023858'

# %%
student_grader.check("q14", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q14...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Function 3: `get_movies(movies_path, mapping_path)`

# %% [markdown]
# We require you to complete the below function to answer the next several questions (this is a **requirement**, and you will **lose points** if you do not implement this function).
#
#
# This function **must** return a **list** of **dictionaries**, where each **dictionary** is of the following format:
#
# ```python
#    {
#         'title': "the movie name",
#         'year': <the year as an integer>,
#         'duration': <the duration as an integer>,
#         'genres': [<genre1>, <genre2>, ...],
#         'rating': <the rating as a float>,
#         'directors': ["director-name1", "director-name2", ...],
#         'cast': ["actor-name1", "actor-name2", ....]
#     }
# ```
#
# Here is an example:
#
# ```python
#     {
#         'title': 'Across the Sierras',
#         'year': 1941,
#         'duration': 59,
#         'genres': ['Western'],
#         'rating': 5.2,
#         'directors': ['D. Ross Lederman'],
#         'cast': ['Dick Curtis', 'Bill Elliott', 'Richard Fiske', 'Luana Walters', 'Dub Taylor']
#     }
# ```
#
# You may use functions that you have already created. Look at lab questions 21-23 for additional guidance.

# %% [markdown]
# Points possible: 5.0

# %%
def get_movies(movies_path, mapping_path):
    """
    get_movies(movies_path, mapping_path) converts a movies csv in 'movies_path' 
    into a list of dicts with column names as keys and the corresponding 
    type converted values as the values; then uses the mapping csv in 'mapping_path'
    to replace the IDs of the titles, cast, and directors into actual names
    """
    raw_movies = get_raw_movies(movies_path)
    mapping_dict = get_mapping(mapping_path) 

    for i in range(len(raw_movies)):
        raw_movies[i]["title"] = mapping_dict[raw_movies[i]["title"]]
        raw_movies[i]["directors"] = [mapping_dict[d] for d in raw_movies[i]["directors"]]
        raw_movies[i]["cast"] = [mapping_dict[c] for c in raw_movies[i]["cast"]]

    return raw_movies
    
    # replace this code
    # Note: you are allowed to call get_mapping and get_raw_movies
    # on `movies_path` and `mapping_path`. Do not harcode the filenames.

# %%
student_grader.check("get_movies", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for get_movies...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 15

# %% [markdown]
# What is returned by `get_movies("movies.csv", "mapping.csv")`?
#
# Your output **must** be a **list** of **dictionaries** where each dictionary contains information about a movie.\
#
# Display the first three movies.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'movies', then display the first 3 movies
movies = get_movies("movies.csv", "mapping.csv")
movies
# Out:
# [{'title': 'Countdown',
#   'year': 1996,
#   'duration': 90,
#   'genres': ['Crime', 'Mystery', 'Thriller'],
#   'rating': 3.9,
#   'directors': ['Keoni Waxman'],
#   'cast': ['Yûki Amami', 'Lori Petty', 'Jason London', 'James Le Gros']},
#  {'title': 'Lost Junction',
#   'year': 2003,
#   'duration': 95,
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'rating': 5.5,
#   'directors': ['Peter Masterson'],
#   'cast': ['Neve Campbell',
#    'Billy Burke',
#    'Jake Busey',
#    'Charles Edwin Powell']},
#  {'title': 'The Stone Council',
#   'year': 2006,
#   'duration': 102,
#   'genres': ['Adventure', 'Crime', 'Drama'],
#   'rating': 4.8,
#   'directors': ['Guillaume Nicloux'],
#   'cast': ['Monica Bellucci',
#    'Catherine Deneuve',
#    'Moritz Bleibtreu',
#    'Sami Bouajila']},
#  {'title': 'Heathers',
#   'year': 1988,
#   'duration': 103,
#   'genres': ['Comedy', 'Crime'],
#   'rating': 7.2,
#   'directors': ['Michael Lehmann'],
#   'cast': ['Winona Ryder',
#    'Christian Slater',
#    'Shannen Doherty',
#    'Lisanne Falk']},
#  {'title': 'Shadows & Lies',
#   'year': 2010,
#   'duration': 100,
#   'genres': ['Crime', 'Drama'],
#   'rating': 4.1,
#   'directors': ['Jay Anania'],
#   'cast': ['James Franco',
#    'Julianne Nicholson',
#    'Martin Donovan',
#    'Josh Lucas']},
#  {'title': 'Assassination of a High School President',
#   'year': 2008,
#   'duration': 93,
#   'genres': ['Comedy', 'Crime', 'Mystery'],
#   'rating': 6.2,
#   'directors': ['Brett Simon'],
#   'cast': ['Reece Thompson',
#    'Mischa Barton',
#    'Bruce Willis',
#    'Michael Rapaport']},
#  {'title': 'And the Spring Comes',
#   'year': 2007,
#   'duration': 94,
#   'genres': ['Drama', 'Music'],
#   'rating': 7.4,
#   'directors': ['Changwei Gu'],
#   'cast': ['Wenli Jiang', 'Guangjie Li', 'Gang Jiao']},
#  {'title': 'Long Live the Bride and Groom',
#   'year': 1970,
#   'duration': 83,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.2,
#   'directors': ['Luis García Berlanga'],
#   'cast': ['José Luis López Vázquez',
#    'Laly Soldevila',
#    'José María Prada',
#    'Manuel Alexandre']},
#  {'title': 'White Gate',
#   'year': 2014,
#   'duration': 86,
#   'genres': ['Drama'],
#   'rating': 6.7,
#   'directors': ['Nicolae Margineanu'],
#   'cast': ['Cat Jugravu',
#    'Cristian Bota',
#    'Sergiu Bucur',
#    'Iulian Burciu',
#    'Radu Bânzaru',
#    'Madalina Craiu',
#    'Constantin Dogioiu']},
#  {'title': 'Lisbela and the Prisoner',
#   'year': 2003,
#   'duration': 106,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 7.6,
#   'directors': ['Guel Arraes'],
#   'cast': ['André Mattos',
#    'Aramis Trindade',
#    'Bruno Garcia',
#    'Carlos Casagrande']},
#  {'title': 'Totò le moko',
#   'year': 1949,
#   'duration': 80,
#   'genres': ['Comedy'],
#   'rating': 6.8,
#   'directors': ['Carlo Ludovico Bragaglia'],
#   'cast': ['Totò', 'Gianna Maria Canale', 'Carla Calò', 'Franca Marzi']},
#  {'title': 'Howling V: The Rebirth',
#   'year': 1989,
#   'duration': 96,
#   'genres': ['Horror'],
#   'rating': 4.4,
#   'directors': ['Neal Sundstrom'],
#   'cast': ['Phil Davis', 'Victoria Catlin', 'Elizabeth Shé', 'Ben Cole']},
#  {'title': 'Agent Cody Banks',
#   'year': 2003,
#   'duration': 102,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'rating': 5.1,
#   'directors': ['Harald Zwart'],
#   'cast': ['Frankie Muniz', 'Hilary Duff', 'Andrew Francis']},
#  {'title': 'There Was Once a King...',
#   'year': 1955,
#   'duration': 107,
#   'genres': ['Comedy', 'Family', 'Fantasy'],
#   'rating': 8.1,
#   'directors': ['Borivoj Zeman'],
#   'cast': ['Jan Werich', 'Vlasta Burian', 'Irena Kacírková', 'Stella Májová']},
#  {'title': 'Clive of India',
#   'year': 1935,
#   'duration': 94,
#   'genres': ['Action', 'Adventure', 'Biography'],
#   'rating': 6.2,
#   'directors': ['Richard Boleslawski'],
#   'cast': ['Ronald Colman', 'Loretta Young', 'Colin Clive', 'Francis Lister']},
#  {'title': 'Le révélateur',
#   'year': 1968,
#   'duration': 67,
#   'genres': ['Drama'],
#   'rating': 6.7,
#   'directors': ['Philippe Garrel'],
#   'cast': ['Laurent Terzieff', 'Bernadette Lafont', 'Stanislas Robiolle']},
#  {'title': 'Mojin: The Lost Legend',
#   'year': 2015,
#   'duration': 127,
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'rating': 5.9,
#   'directors': ['Wuershan'],
#   'cast': ['Kun Chen', 'Huang Bo', 'Shu Qi', 'Angelababy']},
#  {'title': 'Hurt',
#   'year': 2009,
#   'duration': 97,
#   'genres': ['Drama', 'Horror', 'Mystery'],
#   'rating': 5.1,
#   'directors': ['Barbara Stepansky'],
#   'cast': ['Melora Walters',
#    'William Mapother',
#    'Johanna Braddy',
#    'Sofia Vassilieva']},
#  {'title': 'The Only Game in Town',
#   'year': 1970,
#   'duration': 113,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rating': 5.7,
#   'directors': ['George Stevens'],
#   'cast': ['Elizabeth Taylor',
#    'Warren Beatty',
#    'Charles Braswell',
#    'Hank Henry']},
#  {'title': 'Sanctuary',
#   'year': 1961,
#   'duration': 90,
#   'genres': ['Drama'],
#   'rating': 6.1,
#   'directors': ['Tony Richardson'],
#   'cast': ['Lee Remick', 'Yves Montand', 'Bradford Dillman', 'Harry Townes']},
#  {'title': 'Shoot the Moon',
#   'year': 1982,
#   'duration': 124,
#   'genres': ['Drama'],
#   'rating': 6.8,
#   'directors': ['Alan Parker'],
#   'cast': ['Albert Finney', 'Diane Keaton', 'Karen Allen', 'Peter Weller']},
#  {'title': 'Beyond Good and Evil',
#   'year': 1977,
#   'duration': 127,
#   'genres': ['Biography', 'Drama'],
#   'rating': 6.3,
#   'directors': ['Liliana Cavani'],
#   'cast': ['Dominique Sanda',
#    'Erland Josephson',
#    'Robert Powell',
#    'Virna Lisi']},
#  {'title': 'A World Without Women',
#   'year': 2011,
#   'duration': 56,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 7.1,
#   'directors': ['Guillaume Brac'],
#   'cast': ['Vincent Macaigne',
#    'Laure Calamy',
#    'Constance Rousseau',
#    'Laurent Papot']},
#  {'title': 'Raabta',
#   'year': 2017,
#   'duration': 147,
#   'genres': ['Action', 'Drama', 'Fantasy'],
#   'rating': 4.7,
#   'directors': ['Dinesh Vijan'],
#   'cast': ['Kriti Sanon',
#    'Deepika Padukone',
#    'Rajkummar Rao',
#    'Sushant Singh Rajput']},
#  {'title': 'Rain',
#   'year': 2008,
#   'duration': 110,
#   'genres': ['Drama', 'Romance'],
#   'rating': 6.4,
#   'directors': ['Paula Hernández'],
#   'cast': ['Ernesto Alterio',
#    'Valeria Bertuccelli',
#    'Matias Umpierrez',
#    'Osvaldo Djeredjian']},
#  {'title': 'The Butcher',
#   'year': 2006,
#   'duration': 90,
#   'genres': ['Horror', 'Thriller'],
#   'rating': 3.5,
#   'directors': ['Edward Gorsuch'],
#   'cast': ['Catherine Wreford', 'Tom Nagel', 'Myiea Coy', 'Alan Ritchson']},
#  {'title': 'Legends of Flight',
#   'year': 2010,
#   'duration': 45,
#   'genres': ['Documentary'],
#   'rating': 6.1,
#   'directors': ['Stephen Low'],
#   'cast': ['Michael Hanrahan']},
#  {'title': 'Steel City',
#   'year': 2006,
#   'duration': 95,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'rating': 6.3,
#   'directors': ['Brian Jun'],
#   'cast': ['Jamie Anne Allman',
#    'Marcus Atkins',
#    'Raymond J. Barry',
#    'Kristian Best']},
#  {'title': 'The Zombinator',
#   'year': 2012,
#   'duration': 83,
#   'genres': ['Horror'],
#   'rating': 2.2,
#   'directors': ['Sergio Myers'],
#   'cast': ['Patrick Kilpatrick',
#    'Joseph Aviel',
#    'Lucia Brizzi',
#    'Justin Brown']},
#  {'title': 'Office',
#   'year': 2015,
#   'duration': 111,
#   'genres': ['Mystery', 'Thriller'],
#   'rating': 6.0,
#   'directors': ['Won-Chan Hong'],
#   'cast': ['Ko Ah-sung', 'Lee Chae-eun', 'Kim Eui-sung', 'Ryu Hyun-kyung']},
#  {'title': 'Idhu Kathirvelan Kadhal',
#   'year': 2014,
#   'duration': 156,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rating': 4.7,
#   'directors': ['S. Prabhakaran'],
#   'cast': ['Udhayanidhi Stalin', 'Nayanthara', 'Chaya Singh', 'Santhanam']},
#  {'title': 'Two Bits',
#   'year': 1995,
#   'duration': 85,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.1,
#   'directors': ['James Foley'],
#   'cast': ['Al Pacino',
#    'Mary Elizabeth Mastrantonio',
#    'Jerry Barone',
#    'Patrick Borriello']},
#  {'title': 'Rimini',
#   'year': 2022,
#   'duration': 114,
#   'genres': ['Comedy', 'Drama', 'Music'],
#   'rating': 6.9,
#   'directors': ['Ulrich Seidl'],
#   'cast': ['Michael Thomas',
#    'Tessa Göttlicher',
#    'Hans-Michael Rehberg',
#    'Inge Maux']},
#  {'title': 'The Immaculate Room',
#   'year': 2022,
#   'duration': 92,
#   'genres': ['Drama', 'Thriller'],
#   'rating': 5.1,
#   'directors': ['Mukunda Michael Dewil'],
#   'cast': ['Emile Hirsch',
#    'Kate Bosworth',
#    'Ashley Greene',
#    'M. Emmet Walsh']},
#  {'title': 'One Hundred and One Nights',
#   'year': 1995,
#   'duration': 104,
#   'genres': ['Comedy', 'History', 'Romance'],
#   'rating': 6.5,
#   'directors': ['Agnès Varda'],
#   'cast': ['Anouk Aimée',
#    'Michel Piccoli',
#    'Marcello Mastroianni',
#    'Henri Garcin',
#    'Julie Gayet',
#    'Mathieu Demy',
#    'Emmanuel Salinger']},
#  {'title': 'Traxx',
#   'year': 1988,
#   'duration': 84,
#   'genres': ['Action', 'Comedy'],
#   'rating': 5.3,
#   'directors': ['Jerome Gary'],
#   'cast': ['Shadoe Stevens',
#    'Priscilla Barnes',
#    'Willard E. Pugh',
#    'Robert Davi']},
#  {'title': "Die Nibelungen: Kriemhild's Revenge",
#   'year': 1924,
#   'duration': 129,
#   'genres': ['Adventure', 'Drama', 'Fantasy'],
#   'rating': 7.9,
#   'directors': ['Fritz Lang'],
#   'cast': ['Erwin Biswanger',
#    'Margarete Schön',
#    'Gertrud Arnold',
#    'Theodor Loos',
#    'Hans Carl Mueller']},
#  {'title': 'From the Edge of the City',
#   'year': 1998,
#   'duration': 94,
#   'genres': ['Crime', 'Drama'],
#   'rating': 6.4,
#   'directors': ['Constantine Giannaris'],
#   'cast': ['Stathis Papadopoulos',
#    'Costas Kotsianidis',
#    'Panagiotis Chartomatsidis',
#    'Anestis Polychronidis']},
#  {'title': 'Major Saab',
#   'year': 1998,
#   'duration': 165,
#   'genres': ['Action', 'Drama', 'Romance'],
#   'rating': 5.3,
#   'directors': ['Tinnu Anand'],
#   'cast': ['Amitabh Bachchan', 'Ajay Devgn', 'Sonali Bendre', 'Nafisa Ali']},
#  {'title': 'Perfect Strangers',
#   'year': 2022,
#   'duration': 99,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 5.8,
#   'directors': ['Wissam Smayra'],
#   'cast': ['Nadine Labaki', 'Mona Zaki', 'Diamand Abou Abboud', 'Adel Karam']},
#  {'title': 'The Moon Is Blue',
#   'year': 1953,
#   'duration': 99,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 6.7,
#   'directors': ['Otto Preminger'],
#   'cast': ['William Holden', 'David Niven', 'Maggie McNamara', 'Tom Tully']},
#  {'title': 'Ankur: The Seedling',
#   'year': 1974,
#   'duration': 131,
#   'genres': ['Drama'],
#   'rating': 7.8,
#   'directors': ['Shyam Benegal'],
#   'cast': ['Shabana Azmi', 'Sadhu Meher', 'Anant Nag', 'Priya Tendulkar']},
#  {'title': 'Euridice BA 2037',
#   'year': 1975,
#   'duration': 100,
#   'genres': ['Drama', 'Fantasy'],
#   'rating': 6.9,
#   'directors': ['Nikos Nikolaidis'],
#   'cast': ['Vera Tschechowa',
#    'John Moore',
#    'Niki Triantafillidi',
#    'Manolis Logiadis']},
#  {'title': 'Shaadi Mein Zaroor Aana',
#   'year': 2017,
#   'duration': 137,
#   'genres': ['Drama', 'Romance'],
#   'rating': 7.5,
#   'directors': ['Ratnaa Sinha'],
#   'cast': ['Rajkummar Rao', 'Kriti Kharbanda', 'K.K. Raina', 'Alka Amin']},
#  {'title': 'The Ghost Goes West',
#   'year': 1935,
#   'duration': 95,
#   'genres': ['Comedy', 'Fantasy', 'Horror'],
#   'rating': 6.7,
#   'directors': ['René Clair'],
#   'cast': ['Robert Donat',
#    'Jean Parker',
#    'Eugene Pallette',
#    'Elsa Lanchester']},
#  {'title': 'Smokey and the Bandit Part 3',
#   'year': 1983,
#   'duration': 85,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'rating': 3.5,
#   'directors': ['Dick Lowry'],
#   'cast': ['Jackie Gleason', 'Jerry Reed', 'Paul Williams', 'Pat McCormick']},
#  {'title': 'The Cat Misses',
#   'year': 2013,
#   'duration': 106,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rating': 5.0,
#   'directors': ['Mustafa Sevki Dogan'],
#   'cast': ['Ilker Ayrik', 'Algi Eke', 'Erkan Sever', 'Selim Erdogan']},
#  {'title': 'In Love and War',
#   'year': 1996,
#   'duration': 113,
#   'genres': ['Biography', 'Drama', 'Romance'],
#   'rating': 5.9,
#   'directors': ['Richard Attenborough'],
#   'cast': ['Sandra Bullock',
#    "Chris O'Donnell",
#    'Mackenzie Astin',
#    'Margot Steinberg']},
#  {'title': 'The Liquidator',
#   'year': 1965,
#   'duration': 105,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'rating': 5.9,
#   'directors': ['Jack Cardiff'],
#   'cast': ['Rod Taylor',
#    'Trevor Howard',
#    'Jill St. John',
#    'Wilfrid Hyde-White']},
#  {'title': 'Warkop DKI Reborn: Jangkrik Boss Part 2',
#   'year': 2017,
#   'duration': 110,
#   'genres': ['Adventure', 'Comedy'],
#   'rating': 5.5,
#   'directors': ['Anggy Umbara'],
#   'cast': ['Abimana Aryasatya',
#    'Vino G. Bastian',
#    'Tora Sudiro',
#    'Hannah Al Rashid']},
#  {'title': 'None Shall Escape',
#   'year': 1944,
#   'duration': 85,
#   'genres': ['Drama', 'War'],
#   'rating': 7.0,
#   'directors': ['André De Toth'],
#   'cast': ['Marsha Hunt', 'Alexander Knox', 'Henry Travers', 'Erik Rolf']},
#  {'title': "Baby's Day Out",
#   'year': 1994,
#   'duration': 99,
#   'genres': ['Adventure', 'Comedy', 'Crime'],
#   'rating': 6.2,
#   'directors': ['Patrick Read Johnson'],
#   'cast': ['Lara Flynn Boyle',
#    'Joe Mantegna',
#    'Joe Pantoliano',
#    'Brian Haley']},
#  {'title': 'From a Place of Darkness',
#   'year': 2008,
#   'duration': 84,
#   'genres': ['Drama', 'Horror', 'Thriller'],
#   'rating': 3.5,
#   'directors': ['Douglas A. Raine'],
#   'cast': ['Travis Schuldt',
#    'John Savage',
#    'Bronson Pinchot',
#    'Valery M. Ortiz']},
#  {'title': 'By a Sharp Knife',
#   'year': 2019,
#   'duration': 89,
#   'genres': ['Drama'],
#   'rating': 6.5,
#   'directors': ['Teodor Kuhn'],
#   'cast': ['Roman Luknár', 'Ela Lehotská', 'David Hartl', 'Ela Stefunková']},
#  {'title': 'The Killer Meteors',
#   'year': 1976,
#   'duration': 104,
#   'genres': ['Action', 'Thriller'],
#   'rating': 4.9,
#   'directors': ['Wei Lo'],
#   'cast': ['Jackie Chan', 'Jimmy Wang Yu', 'Yu-Li Lan', 'Ling Lung Yu']},
#  {'title': 'Despicable Me 3',
#   'year': 2017,
#   'duration': 89,
#   'genres': ['Adventure', 'Animation', 'Comedy'],
#   'rating': 6.2,
#   'directors': ['Kyle Balda', 'Pierre Coffin', 'Eric Guillon'],
#   'cast': ['Steve Carell', 'Kristen Wiig', 'Trey Parker', 'Miranda Cosgrove']},
#  {'title': 'Expired',
#   'year': 2022,
#   'duration': 102,
#   'genres': ['Action', 'Crime', 'Mystery'],
#   'rating': 3.7,
#   'directors': ['Ivan Sen'],
#   'cast': ['Ryan Kwanten', 'David Field', 'Michael Chan', 'Franck Matour']},
#  {'title': 'Poker',
#   'year': 2010,
#   'duration': 112,
#   'genres': ['Comedy'],
#   'rating': 5.6,
#   'directors': ['Sergiu Nicolaescu'],
#   'cast': ['Vladimir Gaitan',
#    'Horatiu Malaele',
#    'Valentin Teodosiu',
#    'Ion Ritiu']},
#  {'title': 'Two Tickets to Greece',
#   'year': 2022,
#   'duration': 110,
#   'genres': ['Comedy'],
#   'rating': 6.1,
#   'directors': ['Marc Fitoussi'],
#   'cast': ['Laure Calamy',
#    'Olivia Côte',
#    'Kristin Scott Thomas',
#    'Alexandre Desrousseaux']},
#  {'title': 'La señal',
#   'year': 2007,
#   'duration': 95,
#   'genres': ['Crime', 'Drama', 'Mystery'],
#   'rating': 5.9,
#   'directors': ['Martín Hodara'],
#   'cast': ['Ricardo Darín', 'Diego Peretti', 'Julieta Díaz', 'Andrea Pietra']},
#  {'title': 'Kavan',
#   'year': 2017,
#   'duration': 150,
#   'genres': ['Action', 'Drama', 'Thriller'],
#   'rating': 7.1,
#   'directors': ['K.V. Anand'],
#   'cast': ['Vijay Sethupathi',
#    'Madonna Sebastian',
#    'Thesingu Rajendar',
#    'Bose Venkat']},
#  {'title': 'Streets of Laredo',
#   'year': 1949,
#   'duration': 93,
#   'genres': ['Drama', 'Western'],
#   'rating': 6.6,
#   'directors': ['Leslie Fenton'],
#   'cast': ['William Holden',
#    'Macdonald Carey',
#    'Mona Freeman',
#    'William Bendix']},
#  {'title': 'Grease 2',
#   'year': 1982,
#   'duration': 115,
#   'genres': ['Comedy', 'Music', 'Musical'],
#   'rating': 4.5,
#   'directors': ['Patricia Birch'],
#   'cast': ['Michelle Pfeiffer',
#    'Maxwell Caulfield',
#    'Lorna Luft',
#    'Maureen Teefy']},
#  {'title': 'The Misadventures of Margaret',
#   'year': 1998,
#   'duration': 105,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 5.1,
#   'directors': ['Brian Skeet'],
#   'cast': ['Parker Posey',
#    'Jeremy Northam',
#    'Craig Chester',
#    'Elizabeth McGovern']},
#  {'title': 'Last Lives',
#   'year': 1997,
#   'duration': 92,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'rating': 3.7,
#   'directors': ['Worth Keeter'],
#   'cast': ['C. Thomas Howell',
#    'Jennifer Rubin',
#    'Billy Wirth',
#    'Judge Reinhold']},
#  {'title': 'Maskhead',
#   'year': 2009,
#   'duration': 88,
#   'genres': ['Horror'],
#   'rating': 3.5,
#   'directors': ['Rebecca Swan', 'Fred Vogel'],
#   'cast': ['Shelby Lyn Vogel',
#    'Danielle Inks',
#    'Daniel V. Klein',
#    'Michael Witherel']},
#  {'title': 'Nie klam, kochanie',
#   'year': 2008,
#   'duration': 100,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 4.6,
#   'directors': ['Piotr Weresniak'],
#   'cast': ['Piotr Adamczyk',
#    'Marta Zmuda Trzebiatowska',
#    'Beata Tyszkiewicz',
#    'Grazyna Szapolowska']},
#  {'title': 'The Third War',
#   'year': 2020,
#   'duration': 92,
#   'genres': ['Drama'],
#   'rating': 6.0,
#   'directors': ['Giovanni Aloi', 'Andrea Barone'],
#   'cast': ['Anthony Bajon', 'Karim Leklou', 'Leïla Bekhti', 'Arthur Verret']},
#  {'title': 'The Wild Party',
#   'year': 1956,
#   'duration': 91,
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'rating': 5.8,
#   'directors': ['Harry Horner'],
#   'cast': ['Anthony Quinn', 'Carol Ohmart', 'Arthur Franz', 'Jay Robinson']},
#  {'title': 'Return from the River Kwai',
#   'year': 1989,
#   'duration': 101,
#   'genres': ['Drama', 'War'],
#   'rating': 4.9,
#   'directors': ['Andrew V. McLaglen'],
#   'cast': ['Timothy Bottoms', 'Nick Tate', 'George Takei', 'Edward Fox']},
#  {'title': 'Frankenstein General Hospital',
#   'year': 1988,
#   'duration': 90,
#   'genres': ['Comedy', 'Horror', 'Sci-Fi'],
#   'rating': 3.7,
#   'directors': ['Deborah Romare'],
#   'cast': ['Mark Blankfield',
#    'Leslie Jordan',
#    'Jonathan Farwell',
#    'Kathy Shower']},
#  {'title': 'Nadzieja',
#   'year': 2007,
#   'duration': 101,
#   'genres': ['Action', 'Drama', 'Mystery'],
#   'rating': 6.1,
#   'directors': ['Stanislaw Mucha'],
#   'cast': ['Rafal Fudalej',
#    'Kamilla Baar',
#    'Wojciech Pszoniak',
#    'Zbigniew Zapasiewicz']},
#  {'title': '42 Seconds of Happiness',
#   'year': 2016,
#   'duration': 95,
#   'genres': ['Comedy', 'Drama', 'Family'],
#   'rating': 5.8,
#   'directors': ['Christina Kallas'],
#   'cast': ['Laura Pruden',
#    'Becca Ayers',
#    'Vandit Bhatt',
#    'John J. Concado',
#    'Robert Z. Grant',
#    'Margaret Kelly Murphy']},
#  {'title': 'Extra Ordinary Man',
#   'year': 2023,
#   'duration': 157,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'rating': 5.1,
#   'directors': ['Vakkantham Vamsi'],
#   'cast': ['Nithiin', 'Sreeleela', 'Rajasekhar', 'Sudev Nair']},
#  {'title': 'Bad Boy',
#   'year': 1949,
#   'duration': 86,
#   'genres': ['Drama'],
#   'rating': 6.5,
#   'directors': ['Kurt Neumann'],
#   'cast': ['Audie Murphy', 'Lloyd Nolan', 'Jane Wyatt', 'James Gleason']},
#  {'title': 'Dead Wood',
#   'year': 2007,
#   'duration': 85,
#   'genres': ['Horror'],
#   'rating': 3.4,
#   'directors': ['David Bryant', 'Sebastian Smith', 'Richard Stiles'],
#   'cast': ['Fergus March',
#    'Emily Juniper',
#    'John Samuel Worsey',
#    'Rebecca Craven']},
#  {'title': 'The Hidden Face',
#   'year': 2011,
#   'duration': 97,
#   'genres': ['Drama', 'Horror', 'Mystery'],
#   'rating': 7.3,
#   'directors': ['Andrés Baiz'],
#   'cast': ['Martina García', 'María Soledad Rodríguez', 'Jose Luis Garcia']},
#  {'title': 'Unclenching the Fists',
#   'year': 2021,
#   'duration': 97,
#   'genres': ['Drama'],
#   'rating': 6.6,
#   'directors': ['Kira Kovalenko'],
#   'cast': ['Milana Aguzarova',
#    'Alik Karaev',
#    'Soslan Khugaev',
#    'Khetag Bibilov']},
#  {'title': 'Shock to the System',
#   'year': 2006,
#   'duration': 91,
#   'genres': ['Crime', 'Drama', 'Mystery'],
#   'rating': 6.6,
#   'directors': ['Ron Oliver'],
#   'cast': ['Chad Allen',
#    'Sebastian Spence',
#    'Michael Woods',
#    'Daryl Shuttleworth']},
#  {'title': 'The Carson City Kid',
#   'year': 1940,
#   'duration': 57,
#   'genres': ['Drama', 'Western'],
#   'rating': 6.0,
#   'directors': ['Joseph Kane'],
#   'cast': ['Roy Rogers',
#    "George 'Gabby' Hayes",
#    'Bob Steele',
#    'Noah Beery Jr.']},
#  {'title': 'Dynasty Warriors',
#   'year': 2021,
#   'duration': 119,
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'rating': 4.8,
#   'directors': ['Roy Hin Yeung Chow'],
#   'cast': ['Louis Koo', 'Kai Wang', 'Ray Lui', 'Justin Cheung']},
#  {'title': 'Muhammad: The Last Prophet',
#   'year': 2002,
#   'duration': 95,
#   'genres': ['Animation', 'Biography', 'Drama'],
#   'rating': 7.5,
#   'directors': ['Richard Rich'],
#   'cast': ['Nicholas Kadi', 'Richard Epcar', 'Eli Allem', 'David Llewellyn']},
#  {'title': 'Save Your Legs!',
#   'year': 2012,
#   'duration': 92,
#   'genres': ['Comedy', 'Sport'],
#   'rating': 5.6,
#   'directors': ['Boyd Hicklin'],
#   'cast': ['Stephen Curry', 'Brendan Cowell', 'Damon Gameau', 'David Lyons']},
#  {'title': 'Il Prof. Dott. Guido Tersilli primario della Clinica Villa Celeste convenzionata con le mutue',
#   'year': 1969,
#   'duration': 103,
#   'genres': ['Comedy'],
#   'rating': 6.8,
#   'directors': ['Luciano Salce'],
#   'cast': ['Alberto Sordi', 'Ida Galli', 'Pupella Maggio', 'Claudio Gora']},
#  {'title': 'How to Make Good When One Is a Jerk and a Crybaby',
#   'year': 1974,
#   'duration': 90,
#   'genres': ['Comedy'],
#   'rating': 5.7,
#   'directors': ['Michel Audiard'],
#   'cast': ['Jean Carmet',
#    'Stéphane Audran',
#    'Jane Birkin',
#    'Jean-Pierre Marielle']},
#  {'title': 'Fear Street: Part One - 1994',
#   'year': 2021,
#   'duration': 107,
#   'genres': ['Drama', 'Horror', 'Mystery'],
#   'rating': 6.2,
#   'directors': ['Leigh Janiak'],
#   'cast': ['Kiana Madeira',
#    'Olivia Scott Welch',
#    'Benjamin Flores Jr.',
#    'Julia Rehwald']},
#  {'title': 'Hajde da se volimo',
#   'year': 1987,
#   'duration': 87,
#   'genres': ['Comedy', 'Musical'],
#   'rating': 5.1,
#   'directors': ['Aleksandar Djordjevic'],
#   'cast': ['Lepa Brena',
#    'Dragomir Bojanic-Gidra',
#    "Milutin 'Mima' Karadzic",
#    "Svetislav 'Bule' Goncic"]},
#  {'title': 'Una vida no tan simple',
#   'year': 2023,
#   'duration': 107,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rating': 6.5,
#   'directors': ['Félix Viscarret'],
#   'cast': ['Olaya Caldera', 'Miki Esparbé', 'Álex García', 'Ana Polvorosa']},
#  {'title': 'Shadows of Time',
#   'year': 2004,
#   'duration': 122,
#   'genres': ['Drama', 'Romance'],
#   'rating': 7.6,
#   'directors': ['Florian Gallenberger'],
#   'cast': ['Tannishtha Chatterjee',
#    'Prashant Narayanan',
#    'Tillotama Shome',
#    'Irrfan Khan']},
#  {'title': 'Tears for Sale',
#   'year': 2008,
#   'duration': 86,
#   'genres': ['Comedy', 'Drama', 'Fantasy'],
#   'rating': 6.8,
#   'directors': ['Uros Stojanovic'],
#   'cast': ['Katarina Radivojevic',
#    'Sonja Kolacaric',
#    'Stefan Kapicic',
#    'Nenad Jezdic']},
#  {'title': 'Avantazh',
#   'year': 1977,
#   'duration': 138,
#   'genres': ['Drama'],
#   'rating': 7.5,
#   'directors': ['Georgi Djulgerov'],
#   'cast': ['Rousy Chanev',
#    'Plamen Donchev',
#    'Maria Statulova',
#    'Plamena Getova']},
#  {'title': 'Dexter the Dragon & Bumble the Bear',
#   'year': 1983,
#   'duration': 84,
#   'genres': ['Animation', 'Family', 'Fantasy'],
#   'rating': 7.4,
#   'directors': ['Harrie Geelen',
#    'Bjørn Frank Jensen',
#    'Bert Kroon',
#    'Jay Kamen'],
#   'cast': ['Fred Benavente',
#    'Trudy Libosan',
#    'Luc Lutz',
#    'Lo van Hensbergen']},
#  {'title': 'Dujone',
#   'year': 2009,
#   'duration': 136,
#   'genres': ['Romance'],
#   'rating': 5.3,
#   'directors': ['Rajib Biswas'],
#   'cast': ['Debesh Roy Chowdhury',
#    'Arun Bannerjee',
#    'Seema Biswas',
#    'Debjani Chatterjee',
#    'Srabanti Chatterjee']},
#  {'title': 'Alone with You',
#   'year': 2021,
#   'duration': 83,
#   'genres': ['Horror', 'Thriller'],
#   'rating': 4.9,
#   'directors': ['Justin Brooks'],
#   'cast': ['Emily Bennett', 'Emma Myles', 'Darcy Cadman', 'Dora Madison']},
#  {'title': 'Coming Apart',
#   'year': 1969,
#   'duration': 110,
#   'genres': ['Drama'],
#   'rating': 6.6,
#   'directors': ['Milton Moses Ginsberg'],
#   'cast': ['Rip Torn',
#    'Sally Kirkland',
#    'Robert Blankshine',
#    'Darlene Cotton']},
#  {'title': 'El Contrato',
#   'year': 2009,
#   'duration': 95,
#   'genres': ['Action', 'Crime', 'Romance'],
#   'rating': 4.3,
#   'directors': ['Nicolau Breyner'],
#   'cast': ['Pedro Lima', 'Cláudia Vieira', 'Vítor Norte', 'Sofia Aparício']},
#  {'title': 'Enchanted April',
#   'year': 1935,
#   'duration': 66,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rating': 5.7,
#   'directors': ['Harry Beaumont'],
#   'cast': ['Ann Harding',
#    'Frank Morgan',
#    'Katharine Alexander',
#    'Reginald Owen']},
#  {'title': 'Abar',
#   'year': 1977,
#   'duration': 102,
#   'genres': ['Action', 'Drama', 'Sci-Fi'],
#   'rating': 4.2,
#   'directors': ['Frank Packard'],
#   'cast': ['J. Walter Smith', 'Tobar Mayo', 'Roxie Young', 'Gladys Lum']},
#  {'title': 'Pretty Red Dress',
#   'year': 2022,
#   'duration': 110,
#   'genres': ['Drama'],
#   'rating': 6.6,
#   'directors': ['Dionne Edwards'],
#   'cast': ['Natey Jones',
#    'Alexandra Burke',
#    'Temilola Olatunbosun',
#    'Tsemaye Bob-Egbe']},
#  {'title': 'Those Magnificent Men in Their Flying Machines or How I Flew from London to Paris in 25 Hours 11 Minutes',
#   'year': 1965,
#   'duration': 138,
#   'genres': ['Adventure', 'Comedy', 'Family'],
#   'rating': 7.0,
#   'directors': ['Ken Annakin'],
#   'cast': ['Stuart Whitman', 'Sarah Miles', 'James Fox', 'Alberto Sordi']},
#  {'title': 'Palm Trees in the Snow',
#   'year': 2015,
#   'duration': 163,
#   'genres': ['Drama', 'Romance'],
#   'rating': 7.3,
#   'directors': ['Fernando González Molina'],
#   'cast': ['Mario Casas',
#    'Adriana Ugarte',
#    'Macarena García',
#    'Alain Hernández']},
#  {'title': 'Paramedics',
#   'year': 1988,
#   'duration': 90,
#   'genres': ['Comedy'],
#   'rating': 4.1,
#   'directors': ['Stuart Margolin'],
#   'cast': ['George Newbern',
#    'Christopher McDonald',
#    'John P. Ryan',
#    'James Noble']},
#  {'title': 'The Bloody Man',
#   'year': 2020,
#   'duration': 133,
#   'genres': ['Family', 'Horror'],
#   'rating': 2.9,
#   'directors': ['Daniel Benedict'],
#   'cast': ['Lisa Wilcox',
#    'Tuesday Knight',
#    'KateLynn E. Newberry',
#    'Roni Jonah']},
#  {'title': 'Darbaan',
#   'year': 2020,
#   'duration': 88,
#   'genres': ['Drama'],
#   'rating': 7.3,
#   'directors': ['Bipin Nadkarni'],
#   'cast': ['Rasika Dugal', 'Sharib Hashmi', 'Sharad Kelkar', 'Mukesh Ramani']},
#  {'title': 'Irakal',
#   'year': 1985,
#   'duration': 142,
#   'genres': ['Drama'],
#   'rating': 8.2,
#   'directors': ['K.G. George'],
#   'cast': ['Venu Nagavalli',
#    'Ashokan',
#    'Azeez',
#    'P.C. George',
#    'Bharat Gopy',
#    'Mohan Jose',
#    'Ganesh Kumar']},
#  {'title': 'Roseland',
#   'year': 1977,
#   'duration': 104,
#   'genres': ['Drama', 'Music', 'Romance'],
#   'rating': 6.0,
#   'directors': ['James Ivory'],
#   'cast': ['Teresa Wright', 'Lou Jacobi', 'Don De Natale', 'Louise Kirtland']},
#  {'title': 'Die Lümmel von der ersten Bank - 1. Trimester: Zur Hölle mit den Paukern',
#   'year': 1968,
#   'duration': 85,
#   'genres': ['Comedy'],
#   'rating': 5.7,
#   'directors': ['Werner Jacobs'],
#   'cast': ['Hans Kraus',
#    'Gila von Weitershausen',
#    'Günther Schramm',
#    'Hannelore Elsner']},
#  {'title': 'Dancing Quietly',
#   'year': 2016,
#   'duration': 69,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.1,
#   'directors': ['Philipp Eichholtz'],
#   'cast': ['Martina Schöne-Radunski',
#    'Hans-Heinrich Hardt',
#    'Claudia Jacob',
#    'Sebastian Fräsdorf']},
#  {'title': 'Private Network: Who Killed Manuel Buendía?',
#   'year': 2021,
#   'duration': 100,
#   'genres': ['Crime', 'Documentary', 'Mystery'],
#   'rating': 6.8,
#   'directors': ['Manuel Alcalá'],
#   'cast': ['Daniel Giménez Cacho']},
#  {'title': 'Carmín Tropical',
#   'year': 2014,
#   'duration': 80,
#   'genres': ['Drama', 'Mystery'],
#   'rating': 7.1,
#   'directors': ['Rigoberto Pérezcano'],
#   'cast': ['José Pescina',
#    'Luis Alberti',
#    'Everardo Trejo',
#    'Juan Carlos Medellin']},
#  {'title': 'Transcendence',
#   'year': 2014,
#   'duration': 119,
#   'genres': ['Action', 'Drama', 'Sci-Fi'],
#   'rating': 6.2,
#   'directors': ['Wally Pfister'],
#   'cast': ['Johnny Depp', 'Rebecca Hall', 'Morgan Freeman', 'Cillian Murphy']},
#  {'title': 'Discarnate',
#   'year': 2018,
#   'duration': 84,
#   'genres': ['Horror', 'Thriller'],
#   'rating': 4.3,
#   'directors': ['Mario Sorrenti'],
#   'cast': ['Thomas Kretschmann',
#    'Nadine Velazquez',
#    'Bex Taylor-Klaus',
#    'Josh Stewart']},
#  {'title': 'Seven Cities of Gold',
#   'year': 1955,
#   'duration': 103,
#   'genres': ['Adventure', 'Biography', 'History'],
#   'rating': 5.9,
#   'directors': ['Robert D. Webb'],
#   'cast': ['Richard Egan',
#    'Anthony Quinn',
#    'Michael Rennie',
#    'Jeffrey Hunter']},
#  {'title': 'Liam',
#   'year': 2000,
#   'duration': 90,
#   'genres': ['Drama'],
#   'rating': 6.9,
#   'directors': ['Stephen Frears'],
#   'cast': ['Anthony Borrows', 'Ian Hart', 'Claire Hackett', 'David Hart']},
#  {'title': "Let's Get Lost",
#   'year': 1997,
#   'duration': 96,
#   'genres': ['Drama'],
#   'rating': 6.8,
#   'directors': ['Jonas Elmer'],
#   'cast': ['Sidse Babett Knudsen',
#    'Bjarne Henriksen',
#    'Nicolaj Kopernikus',
#    'Troels Lyby']},
#  {'title': 'The Dust of Time',
#   'year': 2008,
#   'duration': 125,
#   'genres': ['Drama'],
#   'rating': 6.6,
#   'directors': ['Theodoros Angelopoulos'],
#   'cast': ['Willem Dafoe', 'Bruno Ganz', 'Michel Piccoli', 'Irène Jacob']},
#  {'title': 'Gambling House',
#   'year': 1950,
#   'duration': 80,
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'rating': 6.2,
#   'directors': ['Ted Tetzlaff'],
#   'cast': ['Victor Mature',
#    'Terry Moore',
#    'William Bendix',
#    'Zachary Charles']},
#  {'title': 'Three Amigos!',
#   'year': 1986,
#   'duration': 104,
#   'genres': ['Comedy', 'Western'],
#   'rating': 6.5,
#   'directors': ['John Landis'],
#   'cast': ['Steve Martin', 'Chevy Chase', 'Martin Short', 'Alfonso Arau']},
#  {'title': 'Leona',
#   'year': 2018,
#   'duration': 94,
#   'genres': ['Drama'],
#   'rating': 6.8,
#   'directors': ['Isaac Cherem'],
#   'cast': ['Naian González Norvind',
#    'Christian Vazquez',
#    'Carolina Politi',
#    'Daniel Adissi']},
#  {'title': 'Suburban Commando',
#   'year': 1991,
#   'duration': 90,
#   'genres': ['Action', 'Comedy', 'Sci-Fi'],
#   'rating': 4.6,
#   'directors': ['Burt Kennedy'],
#   'cast': ['Hulk Hogan',
#    'Christopher Lloyd',
#    'Shelley Duvall',
#    'Larry Miller']},
#  {'title': 'Tango',
#   'year': 1998,
#   'duration': 115,
#   'genres': ['Drama', 'Musical'],
#   'rating': 7.0,
#   'directors': ['Carlos Saura'],
#   'cast': ['Miguel Ángel Solá',
#    'Cecilia Narova',
#    'Mía Maestro',
#    'Juan Carlos Copes']},
#  {'title': 'WTC View',
#   'year': 2005,
#   'duration': 104,
#   'genres': ['Drama', 'Romance'],
#   'rating': 6.1,
#   'directors': ['Brian Sloan'],
#   'cast': ['Michael Urie',
#    'Jeremy Beazlie',
#    'Lucas Papaelias',
#    'Elizabeth Kapplow']},
#  {'title': 'Khamoshi the Musical',
#   'year': 1996,
#   'duration': 160,
#   'genres': ['Drama', 'Musical', 'Romance'],
#   'rating': 7.5,
#   'directors': ['Sanjay Leela Bhansali'],
#   'cast': ['Manisha Koirala', 'Nana Patekar', 'Salman Khan', 'Seema Biswas']},
#  {'title': 'The Top Scorer',
#   'year': 1981,
#   'duration': 81,
#   'genres': ['Action', 'Comedy', 'Romance'],
#   'rating': 6.8,
#   'directors': ['Kartal Tibet'],
#   'cast': ['Reha Yurdakul',
#    'Kemal Sunal',
#    'Yavuz Simsek',
#    'Suna Yildizoglu',
#    'Gölge Basar']},
#  {'title': 'The Snowdrop Festivities',
#   'year': 1984,
#   'duration': 83,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 7.6,
#   'directors': ['Jirí Menzel'],
#   'cast': ['Rudolf Hrusínský', 'Jaromír Hanzlík', 'Josef Somr', 'Petr Cepek']},
#  {'title': 'Guiness',
#   'year': 2009,
#   'duration': 92,
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'rating': 4.8,
#   'directors': ['Alexis Kardaras'],
#   'cast': ['Yorgos Pirpassopoulos',
#    'Markella Giannatou',
#    'Stelios Mainas',
#    'Antonis Kafetzopoulos']},
#  {'title': 'Wanted: Babysitter',
#   'year': 1975,
#   'duration': 110,
#   'genres': ['Crime', 'Thriller'],
#   'rating': 5.4,
#   'directors': ['René Clément'],
#   'cast': ['Maria Schneider', 'Sydne Rome', 'Vic Morrow', 'Robert Vaughn']},
#  {'title': 'Taqdeerwala',
#   'year': 1995,
#   'duration': 162,
#   'genres': ['Action', 'Comedy', 'Fantasy'],
#   'rating': 6.5,
#   'directors': ['K. Muralimohana Rao'],
#   'cast': ['Satyendra Kapoor',
#    'Venkatesh Daggubati',
#    'Raveena Tandon',
#    'Govardhan Asrani',
#    'Laxmikant Berde']},
#  {'title': 'The Last Light',
#   'year': 2014,
#   'duration': 93,
#   'genres': ['Drama', 'Thriller'],
#   'rating': 3.6,
#   'directors': ['Andrew Hyatt'],
#   'cast': ['Edward Furlong', 'Jeff Fahey', 'Molly Hagan', 'Ed Quinn']},
#  {'title': 'Nana',
#   'year': 1955,
#   'duration': 120,
#   'genres': ['Drama', 'Romance'],
#   'rating': 6.3,
#   'directors': ['Christian-Jaque'],
#   'cast': ['Charles Boyer',
#    'Martine Carol',
#    'Walter Chiari',
#    'Paul Frankeur']},
#  {'title': 'The Gore Gore Girls',
#   'year': 1972,
#   'duration': 81,
#   'genres': ['Comedy', 'Crime', 'Horror'],
#   'rating': 5.1,
#   'directors': ['Herschell Gordon Lewis'],
#   'cast': ['Frank Kress', 'Amy Farrell', 'Hedda Lubin', 'Henny Youngman']},
#  {'title': 'The Suicide Squad',
#   'year': 2021,
#   'duration': 132,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'rating': 7.2,
#   'directors': ['James Gunn'],
#   'cast': ['Margot Robbie', 'Idris Elba', 'John Cena', 'Joel Kinnaman']},
#  {'title': 'Choose Connor',
#   'year': 2007,
#   'duration': 109,
#   'genres': ['Drama'],
#   'rating': 6.4,
#   'directors': ['Lucas Elliot Eberl'],
#   'cast': ['Darin Cooper',
#    'Christopher Marquette',
#    'Alex D. Linz',
#    'James Runcorn']},
#  {'title': 'The Damned United',
#   'year': 2009,
#   'duration': 98,
#   'genres': ['Biography', 'Drama', 'Sport'],
#   'rating': 7.5,
#   'directors': ['Tom Hooper'],
#   'cast': ['Colm Meaney', 'Henry Goodman', 'David Roper', 'Jimmy Reddington']},
#  {'title': '47 Meters Down: Uncaged',
#   'year': 2019,
#   'duration': 90,
#   'genres': ['Adventure', 'Drama', 'Horror'],
#   'rating': 5.0,
#   'directors': ['Johannes Roberts'],
#   'cast': ['Sophie Nélisse',
#    'Corinne Foxx',
#    'Brianne Tju',
#    'Sistine Rose Stallone']},
#  {'title': 'Knock at the Cabin',
#   'year': 2023,
#   'duration': 100,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'rating': 6.1,
#   'directors': ['M. Night Shyamalan'],
#   'cast': ['Dave Bautista',
#    'Jonathan Groff',
#    'Ben Aldridge',
#    'Nikki Amuka-Bird']},
#  {'title': 'The Mill on the Po',
#   'year': 1949,
#   'duration': 97,
#   'genres': ['Drama', 'History'],
#   'rating': 7.0,
#   'directors': ['Alberto Lattuada'],
#   'cast': ['Carla Del Poggio',
#    'Jacques Sernas',
#    'Mario Besesti',
#    'Giulio Calì']},
#  {'title': 'Mataharis',
#   'year': 2007,
#   'duration': 100,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.6,
#   'directors': ['Icíar Bollaín'],
#   'cast': ['Najwa Nimri', 'Tristán Ulloa', 'María Vázquez', 'Diego Martín']},
#  {'title': 'Kundschafter des Friedens',
#   'year': 2017,
#   'duration': 93,
#   'genres': ['Action', 'Comedy', 'Thriller'],
#   'rating': 5.9,
#   'directors': ['Robert Thalheim'],
#   'cast': ['Henry Hübchen',
#    'Antje Traue',
#    'Michael Gwisdek',
#    'Thomas Thieme']},
#  {'title': 'My Fairy Troublemaker',
#   'year': 2022,
#   'duration': 85,
#   'genres': ['Adventure', 'Animation', 'Comedy'],
#   'rating': 5.2,
#   'directors': ['Caroline Origer'],
#   'cast': ['Jella Haase', 'Lucy Carolan', 'Alex Avenell', 'Julian Mau']},
#  {'title': 'Heat Wave',
#   'year': 1991,
#   'duration': 110,
#   'genres': ['Crime', 'Drama'],
#   'rating': 6.5,
#   'directors': ['Hideo Gosha'],
#   'cast': ['Kanako Higuchi',
#    'Tatsuya Nakadai',
#    'Keiko Oginome',
#    'Masahiro Motoki']},
#  {'title': 'Spent',
#   'year': 2017,
#   'duration': 100,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 4.5,
#   'directors': ['Lisa Mikitarian'],
#   'cast': ['Connie Lamothe',
#    'Darren Barzegar',
#    'Nick Nerangis',
#    'Madeline Mikitarian']},
#  {'title': 'Big Stone Gap',
#   'year': 2014,
#   'duration': 103,
#   'genres': ['Comedy', 'Family', 'Mystery'],
#   'rating': 5.7,
#   'directors': ['Adriana Trigiani'],
#   'cast': ['Ashley Judd',
#    'Patrick Wilson',
#    'Whoopi Goldberg',
#    'John Benjamin Hickey']},
#  {'title': "Akilla's Escape",
#   'year': 2020,
#   'duration': 90,
#   'genres': ['Crime', 'Drama'],
#   'rating': 5.5,
#   'directors': ['Charles Officer'],
#   'cast': ['Saul Williams',
#    'Thamela Mpumlwana',
#    'Donisha Rita Claire Prendergast',
#    'Vic Mensa']},
#  {'title': 'Le pont des Arts',
#   'year': 2004,
#   'duration': 126,
#   'genres': ['Drama', 'Music'],
#   'rating': 6.9,
#   'directors': ['Eugène Green'],
#   'cast': ['Adrien Michaux',
#    'Natacha Régnier',
#    'Alexis Loret',
#    'Denis Podalydès']},
#  {'title': 'Kansas Pacific',
#   'year': 1953,
#   'duration': 73,
#   'genres': ['Western'],
#   'rating': 5.8,
#   'directors': ['Ray Nazarro'],
#   'cast': ['Sterling Hayden',
#    'Eve Miller',
#    'Barton MacLane',
#    'Harry Shannon']},
#  {'title': 'Carnival Magic',
#   'year': 1983,
#   'duration': 86,
#   'genres': ['Drama', 'Fantasy'],
#   'rating': 2.5,
#   'directors': ['Al Adamson'],
#   'cast': ['Don Stewart',
#    'Jennifer Houlton',
#    'Howard Segal',
#    'Regina Carrol']},
#  {'title': 'Laawaris',
#   'year': 1981,
#   'duration': 189,
#   'genres': ['Action', 'Drama', 'Musical'],
#   'rating': 7.0,
#   'directors': ['Prakash Mehra'],
#   'cast': ['Amitabh Bachchan', 'Zeenat Aman', 'Rakhee Gulzar', 'Amjad Khan']},
#  {'title': 'Masterminds',
#   'year': 1997,
#   'duration': 106,
#   'genres': ['Action', 'Comedy', 'Thriller'],
#   'rating': 5.2,
#   'directors': ['Roger Christian'],
#   'cast': ['Patrick Stewart',
#    'Vincent Kartheiser',
#    'Brenda Fricker',
#    'Bradley Whitford']},
#  {'title': 'The Master Race',
#   'year': 1944,
#   'duration': 95,
#   'genres': ['Drama', 'War'],
#   'rating': 5.9,
#   'directors': ['Herbert J. Biberman'],
#   'cast': ['George Coulouris', 'Stanley Ridges', 'Osa Massen', 'Carl Esmond']},
#  {'title': 'Byzantium',
#   'year': 2012,
#   'duration': 118,
#   'genres': ['Drama', 'Fantasy', 'Horror'],
#   'rating': 6.5,
#   'directors': ['Neil Jordan'],
#   'cast': ['Saoirse Ronan',
#    'Gemma Arterton',
#    'Sam Riley',
#    'Caleb Landry Jones']},
#  {'title': 'Chakravyuha',
#   'year': 2016,
#   'duration': 124,
#   'genres': ['Action', 'Thriller'],
#   'rating': 6.7,
#   'directors': ['M. Saravanan'],
#   'cast': ['Puneeth Rajkumar',
#    'Rachita Ram',
#    'Arun Vijay',
#    'Abhimanyu Singh']},
#  {'title': 'Love Is My Profession',
#   'year': 1958,
#   'duration': 122,
#   'genres': ['Crime', 'Drama', 'Romance'],
#   'rating': 6.7,
#   'directors': ['Claude Autant-Lara'],
#   'cast': ['Jean Gabin',
#    'Brigitte Bardot',
#    'Edwige Feuillère',
#    'Nicole Berger']},
#  {'title': 'Trésor',
#   'year': 2009,
#   'duration': 85,
#   'genres': ['Comedy'],
#   'rating': 4.4,
#   'directors': ['Claude Berri', 'François Dupeyron'],
#   'cast': ['Alain Chabat',
#    'Mathilde Seigner',
#    'Fanny Ardant',
#    'Isabelle Nanty']},
#  {'title': 'Ogni maledetto Natale',
#   'year': 2014,
#   'duration': 95,
#   'genres': ['Comedy'],
#   'rating': 5.6,
#   'directors': ['Giacomo Ciarrapico', 'Mattia Torre', 'Luca Vendruscolo'],
#   'cast': ['Alessandro Cattelan',
#    'Alessandra Mastronardi',
#    'Francesco Pannofino',
#    'Laura Morante']},
#  {'title': 'Doghouse',
#   'year': 2009,
#   'duration': 89,
#   'genres': ['Comedy', 'Horror', 'Sci-Fi'],
#   'rating': 6.0,
#   'directors': ['Jake West'],
#   'cast': ['Danny Dyer', 'Noel Clarke', 'Emil Marwa', 'Lee Ingleby']},
#  {'title': 'Beauty Shop',
#   'year': 2005,
#   'duration': 105,
#   'genres': ['Comedy'],
#   'rating': 5.6,
#   'directors': ['Bille Woodruff'],
#   'cast': ['Queen Latifah',
#    'Alicia Silverstone',
#    'Djimon Hounsou',
#    'Andie MacDowell']},
#  {'title': 'Audition',
#   'year': 1999,
#   'duration': 115,
#   'genres': ['Drama', 'Horror', 'Mystery'],
#   'rating': 7.1,
#   'directors': ['Takashi Miike'],
#   'cast': ['Ryo Ishibashi', 'Eihi Shiina', 'Tetsu Sawaki', 'Jun Kunimura']},
#  {'title': 'Act of Love',
#   'year': 1953,
#   'duration': 95,
#   'genres': ['Drama', 'Romance', 'War'],
#   'rating': 6.5,
#   'directors': ['Anatole Litvak'],
#   'cast': ['Kirk Douglas',
#    'Dany Robin',
#    'Barbara Laage',
#    'Gabrielle Dorziat']},
#  {'title': 'Tarzan and the Amazons',
#   'year': 1945,
#   'duration': 76,
#   'genres': ['Action', 'Adventure'],
#   'rating': 6.2,
#   'directors': ['Kurt Neumann'],
#   'cast': ['Johnny Weissmuller',
#    'Brenda Joyce',
#    'Johnny Sheffield',
#    'Henry Stephenson']},
#  {'title': 'Rampo Noir',
#   'year': 2005,
#   'duration': 134,
#   'genres': ['Fantasy', 'Horror'],
#   'rating': 6.2,
#   'directors': ['Akio Jissôji',
#    'Atsushi Kaneko',
#    'Hisayasu Satô',
#    'Suguru Takeuchi'],
#   'cast': ['Tadanobu Asano', 'Yûko Daike', 'Chisako Hara', 'Masami Horiuchi']},
#  {'title': 'Grosse Pointe Blank',
#   'year': 1997,
#   'duration': 107,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'rating': 7.3,
#   'directors': ['George Armitage'],
#   'cast': ['John Cusack', 'Minnie Driver', 'Dan Aykroyd', 'Joan Cusack']},
#  {'title': 'Man with a Million',
#   'year': 1954,
#   'duration': 90,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 6.8,
#   'directors': ['Ronald Neame'],
#   'cast': ['Gregory Peck',
#    'Jane Griffiths',
#    'Ronald Squire',
#    'Joyce Grenfell']},
#  {'title': 'Ring of Fire II: Blood and Steel',
#   'year': 1993,
#   'duration': 94,
#   'genres': ['Action', 'Drama', 'Sport'],
#   'rating': 4.5,
#   'directors': ['Richard W. Munchkin'],
#   'cast': ['Don Wilson', 'Maria Ford', 'Sy Richardson', 'Dale Jacoby']},
#  {'title': 'Doraemon: Nobita and the Island of Miracles ~Animal Adventure~',
#   'year': 2012,
#   'duration': 100,
#   'genres': ['Action', 'Adventure', 'Animation'],
#   'rating': 6.6,
#   'directors': ['Kôzô Kusuba'],
#   'cast': ['Shihoko Hagino', 'Yumi Kakazu', 'Subaru Kimura', 'Wasabi Mizuta']},
#  {'title': 'A Fairy-Tale Wedding',
#   'year': 2014,
#   'duration': 92,
#   'genres': ['Comedy'],
#   'rating': 5.5,
#   'directors': ['Carlo Vanzina'],
#   'cast': ['Ricky Memphis',
#    'Adriano Giannini',
#    'Emilio Solfrizzi',
#    'Giorgio Pasotti']},
#  {'title': 'Death at Oslo Central',
#   'year': 1990,
#   'duration': 99,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'rating': 6.1,
#   'directors': ['Eva Isaksen'],
#   'cast': ['Håvard Bakke',
#    'Tommy Karlsen',
#    'Helle Beck Figenschow',
#    'Henning Syverud']},
#  {'title': 'Antikiller D.K.',
#   'year': 2009,
#   'duration': 96,
#   'genres': ['Action'],
#   'rating': 5.7,
#   'directors': ['Eldar Salavatov'],
#   'cast': ['Gosha Kutsenko',
#    'Evgeniy Antropov',
#    'Sergey Badyuk',
#    'Yusup Bakhshiev']},
#  {'title': '...and the Fifth Horseman Is Fear',
#   'year': 1965,
#   'duration': 100,
#   'genres': ['Drama', 'War'],
#   'rating': 7.2,
#   'directors': ['Zbynek Brynych'],
#   'cast': ['Miroslav Machácek',
#    'Olga Scheinpflugová',
#    'Zdenka Procházková',
#    'Jirí Adamíra']},
#  {'title': 'Walk the Line',
#   'year': 2005,
#   'duration': 136,
#   'genres': ['Biography', 'Drama', 'Music'],
#   'rating': 7.8,
#   'directors': ['James Mangold'],
#   'cast': ['Joaquin Phoenix',
#    'Reese Witherspoon',
#    'Ginnifer Goodwin',
#    'Robert Patrick']},
#  {'title': 'Vindicta',
#   'year': 2023,
#   'duration': 87,
#   'genres': ['Horror'],
#   'rating': 4.3,
#   'directors': ['Sean McNamara'],
#   'cast': ['Elena Kampouris', 'Jeremy Piven', 'Sean Astin', 'Travis Nelson']},
#  {'title': 'Awaken',
#   'year': 2015,
#   'duration': 89,
#   'genres': ['Action', 'Horror', 'Mystery'],
#   'rating': 3.5,
#   'directors': ['Mark Atkins'],
#   'cast': ['Jason London', 'Robert Davi', 'David Keith', 'Michael Copon']},
#  {'title': 'The Adventure of A.R.I.: My Robot Friend',
#   'year': 2020,
#   'duration': 89,
#   'genres': ['Family', 'Sci-Fi'],
#   'rating': 4.4,
#   'directors': ['Stephen Shimek'],
#   'cast': ['Jude Manley', 'Sophia Alongi', 'J.R. Brown', 'Greg Lutz']},
#  {'title': 'Im Wald',
#   'year': 2022,
#   'duration': 82,
#   'genres': ['Thriller'],
#   'rating': 5.0,
#   'directors': ['Manuel Weiss'],
#   'cast': ['Tobias Kay',
#    'Jolie Joan',
#    'Daniela Mitterlehner',
#    'Reinhard Seyer']},
#  {'title': 'The Infernal Trio',
#   'year': 1974,
#   'duration': 107,
#   'genres': ['Comedy', 'Crime', 'Horror'],
#   'rating': 6.2,
#   'directors': ['Francis Girod'],
#   'cast': ['Michel Piccoli',
#    'Romy Schneider',
#    'Mascha Gonska',
#    'Philippe Brizard']},
#  {'title': 'The Famous Five and the Valley of Dinosaurs',
#   'year': 2018,
#   'duration': 102,
#   'genres': ['Adventure', 'Family'],
#   'rating': 5.3,
#   'directors': ['Mike Marzuk'],
#   'cast': ['Allegra Tinnefeld',
#    'Marinus Hohmann',
#    'Ron Antony Renzenbrink',
#    'Amelie Lammers']},
#  {'title': 'Shubh Yatra',
#   'year': 2023,
#   'duration': 132,
#   'genres': ['Drama', 'Family'],
#   'rating': 7.7,
#   'directors': ['Manish Saini'],
#   'cast': ['Malhar Thakar',
#    'Monal Gajjar',
#    'Darshan Jariwala',
#    'Hemin Trivedi']},
#  {'title': 'Kings',
#   'year': 2007,
#   'duration': 88,
#   'genres': ['Drama'],
#   'rating': 6.7,
#   'directors': ['Tom Collins'],
#   'cast': ['Colm Meaney',
#    "Donal O'Kelly",
#    'Brendan Conroy',
#    'Donncha Crowley']},
#  {'title': 'Eden Is West',
#   'year': 2009,
#   'duration': 110,
#   'genres': ['Drama'],
#   'rating': 6.8,
#   'directors': ['Costa-Gavras'],
#   'cast': ['Riccardo Scamarcio',
#    'Odysseas Papaspiliopoulos',
#    'Léa Wiazemsky',
#    'Tess Spentzos']},
#  {'title': 'Guilt by Design',
#   'year': 2019,
#   'duration': 93,
#   'genres': ['Action', 'Crime'],
#   'rating': 6.0,
#   'directors': ['Siu Kwan Lai', 'Wing Tai Lau', 'Pak-Lam Sze'],
#   'cast': ['Nick Cheung', 'Hans Zhang', 'Eddie Cheung', 'Kent Cheng']},
#  {'title': 'Bright Hill Road',
#   'year': 2020,
#   'duration': 91,
#   'genres': ['Horror'],
#   'rating': 4.5,
#   'directors': ['Robert Cuffley'],
#   'cast': ['Siobhan Williams',
#    'Agam Darshi',
#    'Michael Eklund',
#    'Sally Cacic']},
#  {'title': 'The Anniversary at Shallow Creek',
#   'year': 2011,
#   'duration': 90,
#   'genres': ['Horror', 'Thriller'],
#   'rating': 3.7,
#   'directors': ['Jon D. Wagner'],
#   'cast': ['Katharine Brandt',
#    'Anthony Campanello',
#    'Annie B. Compton',
#    'Eric Fischer']},
#  {'title': 'Thondan',
#   'year': 2017,
#   'duration': 138,
#   'genres': ['Crime'],
#   'rating': 6.1,
#   'directors': ['Samuthirakani'],
#   'cast': ['Gouri Nair',
#    'Arthana Binu',
#    'Gnanasambandan Gurunathan',
#    "'Ganja' Karuppu"]},
#  {'title': 'Cry of the Hunted',
#   'year': 1953,
#   'duration': 80,
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'rating': 6.1,
#   'directors': ['Joseph H. Lewis'],
#   'cast': ['Vittorio Gassman',
#    'Barry Sullivan',
#    'Polly Bergen',
#    'William Conrad']},
#  {'title': 'At Gunpoint',
#   'year': 1955,
#   'duration': 81,
#   'genres': ['Western'],
#   'rating': 6.3,
#   'directors': ['Alfred L. Werker'],
#   'cast': ['Fred MacMurray',
#    'Dorothy Malone',
#    'Walter Brennan',
#    'Tommy Rettig']},
#  {'title': 'Hooked',
#   'year': 2008,
#   'duration': 84,
#   'genres': ['Drama'],
#   'rating': 7.0,
#   'directors': ['Adrian Sitaru'],
#   'cast': ['Adrian Titieni',
#    'Ioana Flora',
#    'Maria Dinulescu',
#    'Alexandru Georgescu']},
#  {'title': 'Deadtime',
#   'year': 2012,
#   'duration': 97,
#   'genres': ['Horror', 'Thriller'],
#   'rating': 2.3,
#   'directors': ['Tony Jopia'],
#   'cast': ['Laurence Saunders',
#    'Carl Coleman',
#    'Elisabeth Shahlavi',
#    'Alex Marieka Hanly']},
#  {'title': 'Extremity',
#   'year': 2018,
#   'duration': 103,
#   'genres': ['Horror', 'Mystery'],
#   'rating': 4.3,
#   'directors': ['Anthony DiBlasi'],
#   'cast': ['Chad Rook', 'Chantal Perron', 'Dana Christina', 'Dylan Sloane']},
#  {'title': 'We Are the Night',
#   'year': 2010,
#   'duration': 99,
#   'genres': ['Drama', 'Fantasy', 'Horror'],
#   'rating': 6.2,
#   'directors': ['Dennis Gansel'],
#   'cast': ['Karoline Herfurth',
#    'Nina Hoss',
#    'Jennifer Ulrich',
#    'Anna Fischer']},
#  {'title': 'Shagird',
#   'year': 2011,
#   'duration': 143,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'rating': 7.0,
#   'directors': ['Tigmanshu Dhulia'],
#   'cast': ['Nana Patekar', 'Mohit Ahlawat', 'Rimi Sen', 'Anurag Kashyap']},
#  {'title': 'Ugly Me',
#   'year': 2006,
#   'duration': 118,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 6.0,
#   'directors': ['Claudio Dabed'],
#   'cast': ['Bárbara Mori',
#    'Marcelo Mazzarello',
#    'Amaya Forch',
#    'Gonzalo Robles']},
#  {'title': 'Seduced and Abandoned',
#   'year': 1964,
#   'duration': 118,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 7.9,
#   'directors': ['Pietro Germi'],
#   'cast': ['Saro Urzì',
#    'Stefania Sandrelli',
#    'Aldo Puglisi',
#    'Lando Buzzanca']},
#  {'title': 'Attack on Titan: The Weight of Pain',
#   'year': 2023,
#   'duration': 155,
#   'genres': ['Action', 'Adventure', 'Animation'],
#   'rating': 6.6,
#   'directors': ['Denis Mosquero Morante'],
#   'cast': ['Yui Ishikawa', 'Yûki Kaji', 'Hiroshi Kamiya']},
#  {'title': 'Earthlings',
#   'year': 2005,
#   'duration': 95,
#   'genres': ['Documentary'],
#   'rating': 8.6,
#   'directors': ['Shaun Monson'],
#   'cast': ['Joaquin Phoenix']},
#  {'title': 'Cuties',
#   'year': 2020,
#   'duration': 96,
#   'genres': ['Drama'],
#   'rating': 3.6,
#   'directors': ['Maïmouna Doucouré'],
#   'cast': ['Fathia Youssouf',
#    'Médina El Aidi-Azouni',
#    'Esther Gohourou',
#    'Ilanah Cami-Goursolas']},
#  {'title': 'Louis & Luca and the Snow Machine',
#   'year': 2013,
#   'duration': 76,
# ...
#    'Alfredo Mayo',
#    'José María Prada',
#    'Emilio Gutiérrez Caba']},
#  {'title': 'A Clockwork Orange',
#   'year': 1971,
#   'duration': 136,
#   'genres': ['Crime', 'Sci-Fi'],
#   'rating': 8.3,
#   'directors': ['Stanley Kubrick'],
#   'cast': ['Malcolm McDowell',
#    'Patrick Magee',
#    'Michael Bates',
#    'Warren Clarke']},
#  {'title': 'A Man Apart',
#   'year': 2003,
#   'duration': 109,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'rating': 6.0,
#   'directors': ['F. Gary Gray'],
#   'cast': ['Vin Diesel', 'Timothy Olyphant', 'Larenz Tate', 'Geno Silva']},
#  {'title': 'Scorned 2',
#   'year': 1997,
#   'duration': 98,
#   'genres': ['Drama', 'Thriller'],
#   'rating': 3.9,
#   'directors': ['Rodney McDonald'],
#   'cast': ['Tane McClure',
#    'Andrew Stevens',
#    "Myles O'Brien",
#    'Alexander Keith']},
#  {'title': 'Causality',
#   'year': 2021,
#   'duration': 114,
#   'genres': ['Drama', 'Mystery', 'Thriller'],
#   'rating': 5.2,
#   'directors': ['Marcelo Politano'],
#   'cast': ['Laura Novoa', 'Juana Viale', 'Esteban Bigliardi', 'Pablo Mónaco']},
#  {'title': 'Ducoboo 2: Crazy Vacation',
#   'year': 2012,
#   'duration': 93,
#   'genres': ['Comedy', 'Family'],
#   'rating': 4.3,
#   'directors': ['Philippe de Chauveron'],
#   'cast': ['Elie Semoun',
#    'Joséphine de Meaux',
#    'Héléna Noguerra',
#    'Pierre-François Martin-Laval']},
#  {'title': 'Hierro',
#   'year': 2009,
#   'duration': 94,
#   'genres': ['Mystery', 'Thriller'],
#   'rating': 5.7,
#   'directors': ['Gabe Ibáñez'],
#   'cast': ['Elena Anaya', 'Bea Segura', 'Mar Sodupe', 'Andrés Herrera']},
#  {'title': 'Watching the Detectives',
#   'year': 2007,
#   'duration': 94,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 6.2,
#   'directors': ['Paul Soter'],
#   'cast': ['Cillian Murphy', 'Lucy Liu', 'Jason Sudeikis', 'Michael Panes']},
#  {'title': 'My Führer',
#   'year': 2007,
#   'duration': 89,
#   'genres': ['Comedy', 'Drama', 'War'],
#   'rating': 5.5,
#   'directors': ['Dani Levy'],
#   'cast': ['Helge Schneider',
#    'Ulrich Mühe',
#    'Sylvester Groth',
#    'Adriana Altaras']},
#  {'title': 'Stonewall',
#   'year': 1995,
#   'duration': 99,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rating': 7.1,
#   'directors': ['Nigel Finch'],
#   'cast': ['Guillermo Diaz',
#    'Frederick Weller',
#    'Brendan Corbalis',
#    'Duane Boutte']},
#  {'title': 'Gold Digger',
#   'year': 2016,
#   'duration': 88,
#   'genres': ['Comedy'],
#   'rating': 5.5,
#   'directors': ['Ville Jankeri'],
#   'cast': ['Minka Kuustonen',
#    'Olavi Uusivirta',
#    'Pamela Tola',
#    'Taneli Mäkelä']},
#  {'title': 'The Story of the Count of Monte Cristo',
#   'year': 1961,
#   'duration': 180,
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'rating': 6.5,
#   'directors': ['Claude Autant-Lara'],
#   'cast': ['Louis Jourdan',
#    'Yvonne Furneaux',
#    'Pierre Mondy',
#    'Bernard Dhéran']},
#  {'title': 'Frits and Freddy',
#   'year': 2010,
#   'duration': 89,
#   'genres': ['Comedy'],
#   'rating': 6.3,
#   'directors': ['Guy Goossens'],
#   'cast': ['Frank Aendenboom',
#    'Stan Lee Cole',
#    'Damiaan De Schrijver',
#    'Tom Dewispelaere']},
#  {'title': 'Little Ukraine',
#   'year': 2022,
#   'duration': 90,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'rating': 4.1,
#   'directors': ['Ante Novakovic'],
#   'cast': ['Yanina Studilina',
#    'Gonzalo Vargas',
#    'Neraida Bega',
#    'Nikolai Tsankov']},
#  {'title': 'Family Life',
#   'year': 1971,
#   'duration': 108,
#   'genres': ['Drama'],
#   'rating': 7.5,
#   'directors': ['Ken Loach'],
#   'cast': ['Sandy Ratcliff', 'Bill Dean', 'Grace Cave', 'Malcolm Tierney']},
#  {'title': 'The Ultimate Warrior',
#   'year': 1975,
#   'duration': 94,
#   'genres': ['Action', 'Sci-Fi'],
#   'rating': 5.6,
#   'directors': ['Robert Clouse'],
#   'cast': ['Yul Brynner', 'Max von Sydow', 'Joanna Miles', 'William Smith']},
#  {'title': 'No Looking Back',
#   'year': 2021,
#   'duration': 101,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'rating': 6.2,
#   'directors': ['Kirill Sokolov'],
#   'cast': ['Igor Grabuzov',
#    'Vitaliy Khaev',
#    'Viktoriya Korotkova',
#    'Sofya Krugova']},
#  {'title': 'Little Cigars',
#   'year': 1973,
#   'duration': 92,
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'rating': 5.3,
#   'directors': ['Chris Christenberry'],
#   'cast': ['Angel Tompkins', 'Billy Curtis', 'Jerry Maren', 'Frank Delfino']},
#  {'title': 'Seeds',
#   'year': 2018,
#   'duration': 90,
#   'genres': ['Horror', 'Thriller'],
#   'rating': 3.8,
#   'directors': ['Owen Long'],
#   'cast': ['Trevor Long', 'Andrea McKinnon', 'Garr Long', 'Kevin Breznahan']},
#  {'title': 'Viva Erotica',
#   'year': 1996,
#   'duration': 99,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.7,
#   'directors': ['Tung-Shing Yee', 'Chi-Leung Law'],
#   'cast': ['Leslie Cheung', 'Karen Mok', 'Shu Qi', 'Ching Wan Lau']},
#  {'title': 'Bunnyman Vengeance',
#   'year': 2017,
#   'duration': 108,
#   'genres': ['Horror'],
#   'rating': 2.9,
#   'directors': ['Carl Lindbergh'],
#   'cast': ['Diana Prince',
#    'Debby Gerber',
#    'Bradley Bundlie',
#    'Marshal Hilton']},
#  {'title': 'Miracle at Sage Creek',
#   'year': 2005,
#   'duration': 90,
#   'genres': ['Action', 'Drama', 'Family'],
#   'rating': 5.7,
#   'directors': ['James Intveld'],
#   'cast': ['David Carradine', 'Wes Studi', 'Michael Parks', 'Tim Abell']},
#  {'title': 'La fille de Monaco',
#   'year': 2008,
#   'duration': 95,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 5.8,
#   'directors': ['Anne Fontaine'],
#   'cast': ['Fabrice Luchini',
#    'Roschdy Zem',
#    'Stéphane Audran',
#    'Gilles Cohen']},
#  {'title': "Fool's Gold",
#   'year': 2008,
#   'duration': 112,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'rating': 5.7,
#   'directors': ['Andy Tennant'],
#   'cast': ['Matthew McConaughey',
#    'Kate Hudson',
#    'Donald Sutherland',
#    'Alexis Dziena']},
#  {'title': "Where's the Party Yaar?",
#   'year': 2003,
#   'duration': 110,
#   'genres': ['Comedy'],
#   'rating': 5.0,
#   'directors': ['Benny Mathews'],
#   'cast': ['Diwakar Pathak',
#    'Sunil Malhotra',
#    'Indravadan Tridevi',
#    'Arun Bakshi']},
#  {'title': 'Gawazah Miri',
#   'year': 2014,
#   'duration': 97,
#   'genres': ['Action', 'Comedy', 'Romance'],
#   'rating': 4.1,
#   'directors': ['Wael Ihsan'],
#   'cast': ['Kerolos Emad',
#    'Yasmin Abdulaziz',
#    'Kareem Mahmoud Abdel Aziz',
#    'Salah Abdullah',
#    'Busi',
#    'Magdy Edris',
#    'Hasan El-Raddad',
#    'Yaser El-Tubgi']},
#  {'title': 'Sr.',
#   'year': 2022,
#   'duration': 89,
#   'genres': ['Biography', 'Documentary'],
#   'rating': 7.2,
#   'directors': ['Chris Smith'],
#   'cast': ['Zaina Ali']},
#  {'title': 'Wrecked',
#   'year': 2010,
#   'duration': 91,
#   'genres': ['Adventure', 'Drama', 'Mystery'],
#   'rating': 5.3,
#   'directors': ['Michael Greenspan'],
#   'cast': ['Adrien Brody',
#    'Caroline Dhavernas',
#    'Ryan Robbins',
#    'Adrian G. Griffiths']},
#  {'title': 'Mother of Mine',
#   'year': 2005,
#   'duration': 111,
#   'genres': ['Drama', 'War'],
#   'rating': 7.6,
#   'directors': ['Klaus Härö'],
#   'cast': ['Topi Majaniemi',
#    'Marjaana Maijala',
#    'Maria Lundqvist',
#    'Michael Nyqvist']},
#  {'title': 'Aa Bhi Ja O Piya',
#   'year': 2022,
#   'duration': 102,
#   'genres': ['Family', 'Romance'],
#   'rating': 7.3,
#   'directors': ['Rajesh Harivansh Mishra'],
#   'cast': ['Sanjeeb Dasgupta',
#    'Pooja Ghosh',
#    'Richa Kalra',
#    'Smriti Kashyap']},
#  {'title': 'Asik Oldum',
#   'year': 1985,
#   'duration': 97,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 6.9,
#   'directors': ['Ertem Egilmez'],
#   'cast': ['Sener Sen', 'Sehnaz Dilan', 'Nevra Serezli', 'Aysen Gruda']},
#  {'title': 'Mesmer',
#   'year': 1994,
#   'duration': 107,
#   'genres': ['Biography', 'Drama'],
#   'rating': 5.9,
#   'directors': ['Roger Spottiswoode'],
#   'cast': ['Donal Donnelly', 'David Burke', 'Peter Dvorsky', 'Alan Rickman']},
#  {'title': 'Meetings with Remarkable Men',
#   'year': 1979,
#   'duration': 108,
#   'genres': ['Biography', 'Drama'],
#   'rating': 7.2,
#   'directors': ['Peter Brook'],
#   'cast': ['Dragan Maksimovic',
#    'Terence Stamp',
#    'Mikica Dimitrijevic',
#    'Athol Fugard']},
#  {'title': 'A Spell to Ward Off the Darkness',
#   'year': 2013,
#   'duration': 98,
#   'genres': ['Documentary', 'Music'],
#   'rating': 6.2,
#   'directors': ['Ben Rivers', 'Ben Russell'],
#   'cast': ['Robert Aiki Aubrey Lowe']},
#  {'title': 'Operation Alamelamma',
#   'year': 2017,
#   'duration': 138,
#   'genres': ['Comedy', 'Thriller'],
#   'rating': 7.9,
#   'directors': ['Suni'],
#   'cast': ['Manish Rishi',
#    'Shraddha Srinath',
#    'Rajesh Nataranga',
#    'Aruna Balaraj']},
#  {'title': 'Lunacy',
#   'year': 2005,
#   'duration': 118,
#   'genres': ['Animation', 'Comedy', 'Drama'],
#   'rating': 7.2,
#   'directors': ['Jan Svankmajer'],
#   'cast': ['Jan Tríska', 'Pavel Liska', 'Anna Geislerová', 'Martin Huba']},
#  {'title': 'Drifting',
#   'year': 2021,
#   'duration': 112,
#   'genres': ['Drama'],
#   'rating': 6.9,
#   'directors': ['Jun Li'],
#   'cast': ['Francis Ng', 'Loletta Lee', 'Cecilia Choi']},
#  {'title': 'Bride of Killer Nerd',
#   'year': 1992,
#   'duration': 75,
#   'genres': ['Comedy', 'Horror'],
#   'rating': 4.2,
#   'directors': ['Mark Steven Bosko', 'Wayne Alan Harold'],
#   'cast': ['Toby Radloff',
#    'Michael Anderson',
#    'Marc Andreyko',
#    'Nina Angeloff']},
#  {'title': 'Far and Away',
#   'year': 1992,
#   'duration': 140,
#   'genres': ['Adventure', 'Drama', 'Romance'],
#   'rating': 6.6,
#   'directors': ['Ron Howard'],
#   'cast': ['Tom Cruise', 'Nicole Kidman', 'Thomas Gibson', 'Robert Prosky']},
#  {'title': 'Firehouse Dog',
#   'year': 2007,
#   'duration': 111,
#   'genres': ['Action', 'Comedy', 'Family'],
#   'rating': 5.5,
#   'directors': ['Todd Holland'],
#   'cast': ['Josh Hutcherson', 'Bruce Greenwood', 'Bree Turner', 'Bill Nunn']},
#  {'title': 'The Soft Skin',
#   'year': 1964,
#   'duration': 113,
#   'genres': ['Drama', 'Romance'],
#   'rating': 7.5,
#   'directors': ['François Truffaut'],
#   'cast': ['Jean Desailly',
#    'Françoise Dorléac',
#    'Nelly Benedetti',
#    'Daniel Ceccaldi']},
#  {'title': 'Crossroads',
#   'year': 1986,
#   'duration': 99,
#   'genres': ['Drama', 'Music', 'Mystery'],
#   'rating': 7.1,
#   'directors': ['Walter Hill'],
#   'cast': ['Ralph Macchio', 'Joe Seneca', 'Jami Gertz', 'Joe Morton']},
#  {'title': 'The Duke',
#   'year': 2020,
#   'duration': 95,
#   'genres': ['Biography', 'Comedy', 'Crime'],
#   'rating': 6.9,
#   'directors': ['Roger Michell'],
#   'cast': ['Jim Broadbent',
#    'Heather Craney',
#    'Stephen Rashbrook',
#    'James Wilby']},
#  {'title': 'The Visitor',
#   'year': 2011,
#   'duration': 70,
#   'genres': ['Drama', 'Romance'],
#   'rating': 5.2,
#   'directors': ['Tor Iben'],
#   'cast': ['Ferhat Türkoglu',
#    'Sinan Hancili',
#    'Engin Sert',
#    'Martina Hesse',
#    'Peter Beck',
#    'Volker Figge',
#    'Oliver Weidner']},
#  {'title': 'Bank Holiday',
#   'year': 1938,
#   'duration': 86,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.4,
#   'directors': ['Carol Reed'],
#   'cast': ['John Lodge', 'Margaret Lockwood', 'Hugh Williams', 'Rene Ray']},
#  {'title': 'Broken Darkness',
#   'year': 2017,
#   'duration': 118,
#   'genres': ['Action', 'Drama', 'Sci-Fi'],
#   'rating': 4.6,
#   'directors': ['Christopher-Lee dos Santos'],
#   'cast': ['Sean Cameron Michael',
#    'Suraya Rose Santos',
#    'Brandon Auret',
#    'Brendan Sean Murray']},
#  {'title': 'Thale',
#   'year': 2012,
#   'duration': 76,
#   'genres': ['Drama', 'Fantasy', 'Horror'],
#   'rating': 5.5,
#   'directors': ['Aleksander Nordaas'],
#   'cast': ['Silje Reinåmo',
#    'Erlend Nervold',
#    'Jon Sigve Skard',
#    'Morten Andresen']},
#  {'title': 'Catch Me Daddy',
#   'year': 2014,
#   'duration': 112,
#   'genres': ['Drama', 'Thriller'],
#   'rating': 6.3,
#   'directors': ['Daniel Wolfe', 'Matthew Wolfe'],
#   'cast': ['Sameena Jabeen Ahmed',
#    'Conor McCarron',
#    'Gary Lewis',
#    'Nichola Burley']},
#  {'title': 'Kidnap',
#   'year': 2007,
#   'duration': 93,
#   'genres': ['Crime', 'Thriller'],
#   'rating': 5.8,
#   'directors': ['Chi-Leung Law'],
#   'cast': ['Karena Kar-Yan Lam', 'Rene Liu', 'Julian Cheung', 'Eddie Cheung']},
#  {'title': '1918',
#   'year': 1985,
#   'duration': 94,
#   'genres': ['Drama'],
#   'rating': 6.0,
#   'directors': ['Ken Harrison'],
#   'cast': ['William Converse-Roberts',
#    'Hallie Foote',
#    'Matthew Broderick',
#    'Rochelle Oliver']},
#  {'title': 'Freelance',
#   'year': 2023,
#   'duration': 108,
#   'genres': ['Action', 'Comedy'],
#   'rating': 5.5,
#   'directors': ['Pierre Morel'],
#   'cast': ['John Cena', 'Alison Brie', 'Juan Pablo Raba', 'Christian Slater']},
#  {'title': 'No Tears for the Dead',
#   'year': 2014,
#   'duration': 116,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'rating': 6.7,
#   'directors': ['Lee Jeong-beom'],
#   'cast': ['Kim Min-hee', 'Brian Tee', 'Kim Hee-won']},
#  {'title': 'Three Days to Eternity',
#   'year': 2007,
#   'duration': 104,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 7.0,
#   'directors': ['Riri Riza'],
#   'cast': ['Inong Ayu', 'Bowie Budianto', 'Chichi Kadijono', 'Tutie Kirana']},
#  {'title': 'The Love Witch',
#   'year': 2016,
#   'duration': 120,
#   'genres': ['Comedy', 'Horror', 'Romance'],
#   'rating': 6.2,
#   'directors': ['Anna Biller'],
#   'cast': ['Samantha Robinson',
#    'Jeffrey Vincent Parise',
#    'Laura Waddell',
#    'Gian Keys']},
#  {'title': 'Ne Olacak Simdi',
#   'year': 1979,
#   'duration': 83,
#   'genres': ['Comedy', 'Romance'],
#   'rating': 7.5,
#   'directors': ['Atif Yilmaz'],
#   'cast': ['Levent Kirca', 'Nevra Serezli', 'Sener Sen', 'Perran Kutman']},
#  {'title': 'Mei',
#   'year': 2019,
#   'duration': 112,
#   'genres': ['Action'],
#   'rating': 6.0,
#   'directors': ['Sa Baskaran'],
#   'cast': ['Gowthami Vembunathan',
#    'Charle',
#    'Kishore Kumar G.',
#    'Ajay Ghosh',
#    'Vinod Krishnan',
#    'Aishwarya Rajesh']},
#  {'title': 'Dishoom',
#   'year': 2016,
#   'duration': 124,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'rating': 5.1,
#   'directors': ['Rohit Dhawan'],
#   'cast': ['John Abraham',
#    'Varun Dhawan',
#    'Jacqueline Fernandez',
#    'Akshaye Khanna']},
#  {'title': 'The Optimists',
#   'year': 1973,
#   'duration': 110,
#   'genres': ['Drama'],
#   'rating': 6.6,
#   'directors': ['Anthony Simmons'],
#   'cast': ['Peter Sellers', 'Donna Mullane', 'John Chaffey', 'David Daker']},
#  {'title': 'Trip Out',
#   'year': 2005,
#   'duration': 93,
#   'genres': ['Drama'],
#   'rating': 5.7,
#   'directors': ['James M. Hausler'],
#   'cast': ['Christopher M. Clark',
#    'Taylor Coffman',
#    'Sean Galdo',
#    'Christopher Gillespie']},
#  {'title': 'Future Cops',
#   'year': 1993,
#   'duration': 95,
#   'genres': ['Action', 'Comedy', 'Sci-Fi'],
#   'rating': 5.9,
#   'directors': ['Jing Wong'],
#   'cast': ['Ekin Cheng',
#    'Andy Lau',
#    'Jacky Cheung',
#    'Aaron Kwok',
#    'Chingmy Yau',
#    'Dicky Cheung',
#    'Simon Yam']},
#  {'title': 'Kim Ji-young: Born 1982',
#   'year': 2019,
#   'duration': 118,
#   'genres': ['Drama'],
#   'rating': 7.3,
#   'directors': ['Kim Do-Young'],
#   'cast': ['Jung Yu-mi', 'Gong Yoo', 'Kim Mi-kyung', 'Kim Sung-cheol']},
#  {'title': 'Nad Niemnem',
#   'year': 1987,
#   'duration': 215,
#   'genres': ['Drama', 'History', 'Romance'],
#   'rating': 6.3,
#   'directors': ['Zbigniew Kuzminski'],
#   'cast': ['Iwona Katarzyna Pawlak',
#    'Adam Marjanski',
#    'Marta Lipinska',
#    'Janusz Zakrzenski']},
#  {'title': 'Saint Seiya: Legend of Crimson Youth',
#   'year': 1988,
#   'duration': 71,
#   'genres': ['Action', 'Animation', 'Fantasy'],
#   'rating': 7.3,
#   'directors': ['Shigeyasu Yamauchi'],
#   'cast': ['Tôru Furuya',
#    'Hirotaka Suzuoki',
#    'Hideyuki Hori',
#    'Ryô Horikawa']},
#  {'title': 'Killing for the Prosecution',
#   'year': 2018,
#   'duration': 123,
#   'genres': ['Mystery'],
#   'rating': 6.3,
#   'directors': ['Masato Harada'],
#   'cast': ['Takuya Kimura',
#    'Kazunari Ninomiya',
#    'Yuriko Yoshitaka',
#    'Takehiro Hira']},
#  {'title': 'The House of the Spirits',
#   'year': 1993,
#   'duration': 145,
#   'genres': ['Drama', 'Romance'],
#   'rating': 6.9,
#   'directors': ['Bille August'],
#   'cast': ['Jeremy Irons',
#    'Meryl Streep',
#    'Maria Conchita Alonso',
#    'António Assunção']},
#  {'title': 'My Santa',
#   'year': 2019,
#   'duration': 153,
#   'genres': ['Comedy', 'Drama', 'Fantasy'],
#   'rating': 5.6,
#   'directors': ['Sugeeth'],
#   'cast': ['Dileep', 'Manasvi', 'Saikumar', 'Sunny Wayne']},
#  {'title': 'Body Weapon',
#   'year': 1999,
#   'duration': 91,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'rating': 4.1,
#   'directors': ['Aman Chang'],
#   'cast': ['Rocky Lai', 'Wenzhuo Zhao', 'Stephen Au', 'Elvis Tsui']}]

# %%
student_grader.check("q15", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q15...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# **Warning**: You are **not** allowed to call `get_movies` more than once on the full dataset (`movies.csv` and `mapping.csv`) in your notebook. Instead, reuse the `movies` variable, which is more efficient. The autograder will deduct **points** if you call `get_movies` again on these files.
#
# **Warning:** Do **not** display the value of the variable `movies` **anywhere** in your notebook. It will take up a **lot** of space, and your **code will not be displayed** for grading. Instead you should verify `movies` has the correct value by looking at a small *slice* of the **list** as in the question below.

# %% [markdown]
# #### Project Question 16

# %% [markdown]
# What is `title` of the **second** movie in `movies`?
#
# Your output **must** be a **string**. You **must** use the variable `movies` defined above to answer this question. You **must not** call the function `get_movies` again on this dataset.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'second_movie_title_movies', then display it
second_movie_title_movies = movies[1]["title"]
second_movie_title_movies
# Out:
# 'Lost Junction'

# %%
student_grader.check("q16", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q16...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 17

# %% [markdown]
# Who are the `cast` members of the **second** movie in `movies`?
#
# Your output **must** be a **list** of **string(s)** stored in a new variable named `second_movie_cast_movies`. You **must** use the variable `movies` defined above to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'second_movie_cast_movies', then display it
second_movie_cast_movies = movies[1]["cast"]
second_movie_cast_movies
# Out:
# ['Neve Campbell', 'Billy Burke', 'Jake Busey', 'Charles Edwin Powell']

# %%
student_grader.check("q17", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q17...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 18

# %% [markdown]
# Who are the `directors` of the **last** movie in `movies`?
#
# Your output **must** be a **list** of **string(s)** stored in a new variable named `last_movie_directors_movies`. You **must** use the variable `movies` defined above to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'last_movie_directors_movies', then display it
last_movie_directors_movies = movies[-1]["directors"]
last_movie_directors_movies
# Out:
# ['Aman Chang']

# %%
student_grader.check("q18", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q18...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 19

# %% [markdown]
# What are the movies in `movies[130:140]`?

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'movies_130_140', then display it
movies_130_140 = movies[130:140]
movies_130_140
# Out:
# [{'title': 'The Gore Gore Girls',
#   'year': 1972,
#   'duration': 81,
#   'genres': ['Comedy', 'Crime', 'Horror'],
#   'rating': 5.1,
#   'directors': ['Herschell Gordon Lewis'],
#   'cast': ['Frank Kress', 'Amy Farrell', 'Hedda Lubin', 'Henny Youngman']},
#  {'title': 'The Suicide Squad',
#   'year': 2021,
#   'duration': 132,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'rating': 7.2,
#   'directors': ['James Gunn'],
#   'cast': ['Margot Robbie', 'Idris Elba', 'John Cena', 'Joel Kinnaman']},
#  {'title': 'Choose Connor',
#   'year': 2007,
#   'duration': 109,
#   'genres': ['Drama'],
#   'rating': 6.4,
#   'directors': ['Lucas Elliot Eberl'],
#   'cast': ['Darin Cooper',
#    'Christopher Marquette',
#    'Alex D. Linz',
#    'James Runcorn']},
#  {'title': 'The Damned United',
#   'year': 2009,
#   'duration': 98,
#   'genres': ['Biography', 'Drama', 'Sport'],
#   'rating': 7.5,
#   'directors': ['Tom Hooper'],
#   'cast': ['Colm Meaney', 'Henry Goodman', 'David Roper', 'Jimmy Reddington']},
#  {'title': '47 Meters Down: Uncaged',
#   'year': 2019,
#   'duration': 90,
#   'genres': ['Adventure', 'Drama', 'Horror'],
#   'rating': 5.0,
#   'directors': ['Johannes Roberts'],
#   'cast': ['Sophie Nélisse',
#    'Corinne Foxx',
#    'Brianne Tju',
#    'Sistine Rose Stallone']},
#  {'title': 'Knock at the Cabin',
#   'year': 2023,
#   'duration': 100,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'rating': 6.1,
#   'directors': ['M. Night Shyamalan'],
#   'cast': ['Dave Bautista',
#    'Jonathan Groff',
#    'Ben Aldridge',
#    'Nikki Amuka-Bird']},
#  {'title': 'The Mill on the Po',
#   'year': 1949,
#   'duration': 97,
#   'genres': ['Drama', 'History'],
#   'rating': 7.0,
#   'directors': ['Alberto Lattuada'],
#   'cast': ['Carla Del Poggio',
#    'Jacques Sernas',
#    'Mario Besesti',
#    'Giulio Calì']},
#  {'title': 'Mataharis',
#   'year': 2007,
#   'duration': 100,
#   'genres': ['Comedy', 'Drama'],
#   'rating': 6.6,
#   'directors': ['Icíar Bollaín'],
#   'cast': ['Najwa Nimri', 'Tristán Ulloa', 'María Vázquez', 'Diego Martín']},
#  {'title': 'Kundschafter des Friedens',
#   'year': 2017,
#   'duration': 93,
#   'genres': ['Action', 'Comedy', 'Thriller'],
#   'rating': 5.9,
#   'directors': ['Robert Thalheim'],
#   'cast': ['Henry Hübchen',
#    'Antje Traue',
#    'Michael Gwisdek',
#    'Thomas Thieme']},
#  {'title': 'My Fairy Troublemaker',
#   'year': 2022,
#   'duration': 85,
#   'genres': ['Adventure', 'Animation', 'Comedy'],
#   'rating': 5.2,
#   'directors': ['Caroline Origer'],
#   'cast': ['Jella Haase', 'Lucy Carolan', 'Alex Avenell', 'Julian Mau']}]

# %%
student_grader.check("q19", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q19...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 20

# %% [markdown]
# What is the **number** of movies in the dataset released in `year` *2023*?
#
# Your output must be an **int** stored in a new variable named `num_movies_2023`. You **must** use the variable `movies` defined above to answer this question.

# %% [markdown]
# Points possible: 4.0

# %%
# compute and store the answer in the variable 'num_movies_2023', then display it
num_movies_2023 = 0 

for movie in movies:
    if movie["year"] == 2023:
        num_movies_2023 += 1
        
num_movies_2023
# Out:
# 33

# %%
student_grader.check("q20", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q20...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Function 4: `find_specific_movies(movies, keyword)`

# %% [markdown]
# Now that we have created this data structure `movies`, we can start doing some fun things with the data!
# We will continue working on this data structure for the next project (P9) as well.
#
# Let us now use this data structure `movies` to create a **search bar** like the one in Netflix!
# **Do not change the below function in any way**.
# This function takes in a keyword like a substring of a title, a genre, or the name of a person, and returns a list of relevant movies with that title, genre, or cast member/director.
#
# **Warning:** As `movies` is very large, the function `find_specific_movies` may take five to ten seconds to run. This is normal and you should not panic if it takes a while to run.

# %%
# DO NOT EDIT THIS CELL AND DO NOT REDEFINE THIS FUNCTION ELSEWHERE
def find_specific_movies(movies, keyword):
    """
    find_specific_movies(movies, keyword) takes a list of movie dictionaries 
    and a keyword; it returns a list of movies that contain the keyword
    in either its title, genre, cast or directors.
    """
    idx = 0
    while idx < len(movies):
        movie = movies[idx]
        # note: \ enables you split a long line of code into two lines
        if (keyword not in movie['title']) and (keyword not in movie["genres"]) \
        and (keyword not in movie["directors"]) and (keyword not in movie["cast"]):
            movies.pop(idx)
        else:
            idx += 1
    return movies

# %% [markdown]
# **Important:** While it might look as if we are making it easy for you by providing `find_specific_movies`, there is a catch! There is a subtle flaw with the way the function is defined, that will cause you issues in the next two questions. If you can spot this flaw by just observing the definition of `find_specific_movies`, congratulations! Since you are **not** allowed to modify the function definition, you will have to be a little clever with your function arguments to sidestep the flaw with the function definition.
#
# If you don't see anything wrong with the function just yet, don't worry about it. Solve Question 21 and Question 22 as you normally would, and see if you notice anything suspicious about your answers.

# %% [markdown]
# #### Project Question 21

# %% [markdown]
# Find all movies related to Willem Dafoe. Your answer **must** be a **list** of **dictionaries**. You **must** answer this question by calling `find_specific_movies` with the keyword `"Willem Dafoe"`.
#
# Remember that you are **not** allowed to modify the definition of `find_specific_movies`. You will need to cleverly pass arguments to `find_specific_movies` (in both Question 21 and Question 22) to ensure that `movies` does not get modified by the function calls. Take a look at the lecture notebooks on **Copying** to better understand. If calling the function modifies your `movies` data when you answer Question 21 or 22 then you will have to restart and run all your cells to properly set the `movies` variable back to hold the right information.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'dafoe_films', then display it
dafoe_films = find_specific_movies(copy.copy(movies), "Willem Dafoe")
dafoe_films
# Out:
# [{'title': 'The Dust of Time',
#   'year': 2008,
#   'duration': 125,
#   'genres': ['Drama'],
#   'rating': 6.6,
#   'directors': ['Theodoros Angelopoulos'],
#   'cast': ['Willem Dafoe', 'Bruno Ganz', 'Michel Piccoli', 'Irène Jacob']},
#  {'title': 'Dead for a Dollar',
#   'year': 2022,
#   'duration': 107,
#   'genres': ['Action', 'Drama', 'Western'],
#   'rating': 5.4,
#   'directors': ['Walter Hill'],
#   'cast': ['Christoph Waltz',
#    'Willem Dafoe',
#    'Rachel Brosnahan',
#    'Warren Burke']},
#  {'title': 'Tom & Viv',
#   'year': 1994,
#   'duration': 125,
#   'genres': ['Biography', 'Drama', 'Romance'],
#   'rating': 6.3,
#   'directors': ['Brian Gilbert'],
#   'cast': ['Willem Dafoe',
#    'Miranda Richardson',
#    'Rosemary Harris',
#    'Tim Dutton']}]

# %%
student_grader.check("q21", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q21...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 22

# %% [markdown]
# List all the movies that contain the string `"Night"`.
#
# Your answer **must** be a **list** of **dictionaries**.
#
# You **must** answer this question by calling `find_specific_movies` with the keyword `"Night"`.
#
# **Important Hint:**  If you did not notice the flaw with the definition of `find_specific_movies` before, you are likely to have run into an issue with this question. It is likely that you will see that your output for this question is an empty list. To see why this happened, find the value of `len(movies)` and see if it is equal to the value you found earlier.

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'night_movies', then display it
import copy
movies_copy = copy.copy(movies)
night_movies = find_specific_movies(movies_copy, "Night")
print(len(night_movies))
# Out:
# 12

# %%
student_grader.check("q22", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q22...
# 12
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Function 5: `bucketize_by_genre(movies)`

# %% [markdown]
# We require you to complete the below function to answer the next several questions (this is a **requirement**, and you will **lose points** if you do not implement this function).

# %% [markdown]
# Points possible: 5.0

# %%
def bucketize_by_genre(movies):
    """bucketize_by_genre(movies) takes a list of movie dictionaries;
    it returns a dict in which each genre is a key and
    the value is a list of all movies that contain that genre"""
     
    i_dict = {}
    for movie in movies:
        for genre in movie["genres"]:
            if genre not in i_dict:
                i_dict[genre] = []
            i_dict[genre].append(movie)

    return i_dict

    
    # replace with your code
    # TODO: initialize a dictionary
    # TODO: loop through all movies
    # TODO:     loop through all genres in this movie
    # TODO:         if this genre is not a key in our dictionary, set the value associated with this genre to an empty list
    # TODO:         add the movie to the list associated with this genre
    # TODO: return the dictionary

# %%
student_grader.check("bucketize_by_genre", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for bucketize_by_genre...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# **Warning:** You are **not** allowed to call `bucketize_by_genre` more than once on the full list of movies (`movies`) in your notebook. The autograder will **deduct points** if you call `bucketize_by_genre` again on `movies`.

# %%
# call the function bucketize_by_genre on 'movies' and store it in the variable 'genre_dict'
# do NOT display the output directly

genre_dict = bucketize_by_genre(movies)

# %% [markdown]
# #### Project Question 23

# %% [markdown]
# How many **unique** movie `genres` are present in the dataset?

# %% [markdown]
# Points possible: 2.0

# %%
# compute and store the answer in the variable 'num_genres', then display it
num_genres = len(genre_dict)
num_genres
# Out:
# 22

# %%
student_grader.check("q23", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q23...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 24

# %% [markdown]
# How many *Romance* movies (i.e. movies with *Romance* as one of their `genres`) do we have in the dataset released **after** the `year` *2019*?
#
# Your output **must** be an **int** stored in a new variable named `romance_after_2019`. You **must** use the `genre_dict` data structure to answer this question.

# %% [markdown]
# Points possible: 4.0

# %%
# compute and store the answer in the variable 'romance_after_2019', then display it
romance_after_2019 = 0

for movie in genre_dict["Romance"]:
    if movie["year"] > 2019:
                romance_after_2019 += 1
        
romance_after_2019
# Out:
# 24

# %%
student_grader.check("q24", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q24...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 25

# %% [markdown]
# List the `title` of all *Documentary* movies (i.e. movies with *Documentary* as one of their `genres`) with `duration` **larger** than *90* in the dataset.
#
# Your output **must** be a **list** of **strings** stored in a new variable named `docs_longer_than_90_mins`. You **must** use the `genre_dict` data structure to answer this question.

# %% [markdown]
# Points possible: 5.0

# %%
# compute and store the answer in the variable 'docs_longer_than_90_mins', then display it
docs_longer_than_90_mins = []

for movie in genre_dict["Documentary"]:
    if movie["duration"] > 90:
        docs_longer_than_90_mins.append(movie['title'])
        
docs_longer_than_90_mins
# Out:
# ['Private Network: Who Killed Manuel Buendía?',
#  'Earthlings',
#  'Raul: O Início, o Fim e o Meio',
#  'Moby Doc',
#  "Aurora's Sunrise",
#  'Listen to Me Marlon',
#  'Stop The Pounding Heart',
#  'A Spell to Ward Off the Darkness']

# %%
student_grader.check("q25", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q25...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 26

# %% [markdown]
# Which movie `genre` is *Nana Patekar* the most involved with?
#
# We say that *Nana Patekar* is involved with a movie if they is **either** a *director* **or** a *cast member* of that movie. You need to find the movie `genre` with the **highest** number of movies that *Nana Patekar* is involved with. There is a **unique** `genre` that *Nana Patekar* is most involved with. You do **not** have to worry about breaking ties. You may **assume** that there are **no** movies in the dataset with the string `"Nana Patekar"` in their `title`.
#
# Your output **must** be a **string** stored in a new variable named `patekar_genre`.
#
# **Hint:** You can combine the *two* functions above (`find_specific_movies` and `bucketize_by_genre`) to bucketize **only** the movies that *Nana Patekar* was involved with by their `genres`. Then, you can loop through each genre to find the one with the most number of movies in it.

# %% [markdown]
# Points possible: 5.0

# %%
# compute and store the answer in the variable 'patekar_genre', then display it
movie_involving_patekar = find_specific_movies(movies.copy(),"Nana Patekar")
movies_by_genre = bucketize_by_genre(movie_involving_patekar)

patekar_genre = ""
num_patekar = 0

for genre, movie_list in movies_by_genre.items():
    current_count = len(movie_list)
    if current_count > num_patekar:
        num_patekar = current_count 
        patekar_genre = genre
        
patekar_genre
# Out:
# 'Drama'

# %%
student_grader.check("q26", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q26...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# #### Project Question 27

# %% [markdown]
# Who are the `directors` of the *Horror* movies with the **highest** `rating` in the movies dataset?
#
# You **must** output a **list** of **strings** containing the **names** of **all** the `directors` of **all** these movies. The output must be stored in a new variable named `max_horror_rating_directors`. Your code should work if there are multiple horror movies with the highest rating.
#
# **Hint:** If you are unsure how to efficiently add the elements of one list to another, please review the lecture notes about lists.

# %% [markdown]
# Points possible: 5.0

# %%
# compute and store the answer in the variable 'max_horror_rating_directors', then display it
movies_by_genre = bucketize_by_genre(movies)
max_horror_rating_directors = []
highest_rat = 0

for movie in movies_by_genre["Horror"]:
    current_rat = movie['rating']
    if current_rat > highest_rat:
        highest_rat = current_rat
        max_horror_rating_directors = movie['directors']
    elif current_rat == highest_rat:
        max_horror_rating_directors.extend(movie['directors'])
        
max_horror_rating_directors = max_horror_rating_directors
max_horror_rating_directors
# Out:
# ['Andrés Baiz', 'Anurag Kashyap']

# %%
student_grader.check("q27", should_get_llm_feedback=False)
# Out:
# Make sure you saved the notebook before running this cell. Running check for q27...
# Great job! You passed all test cases for this question.
# True

# %% [markdown]
# ### Submission
#
# Make sure you have run all cells in your notebook in order before submitting on Gradescope. Your notebook should not contain any uncaught Exceptions, otherwise the Gradescope autograder will not give you any points.
